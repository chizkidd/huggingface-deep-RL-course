# %% [markdown]
# <a href="https://colab.research.google.com/github/chizkidd/huggingface-deep-RL-course/blob/main/notebooks/units/unit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 1: Train your first Deep Reinforcement Learning Agent 🤖
#
# ![Cover](https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/thumbnail.jpg)
#
# In this notebook, you'll train your **first Deep Reinforcement Learning agent** a Lunar Lander agent that will learn to **land correctly on the Moon 🌕**. Using [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) a Deep Reinforcement Learning library, share them with the community, and experiment with different configurations
#
# ⬇️ Here is an example of what **you will achieve in just a couple of minutes.** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### The environment 🎮
#
# - [LunarLander-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# ### The library used 📚
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Gymnasium**, the environment library.
# - Be able to use **Stable-Baselines3**, the deep reinforcement learning library.
# - Be able to **push your trained agent to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
# - 🎓 **Earn a certificate of completion** by completing 80% of the assignments.
#
# And more!
#
# Check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
# The best way to keep in touch and ask questions is **to join our discord server** to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
#
# Before diving into the notebook, you need to:
#
# 🔲 📝 **[Read Unit 0](https://huggingface.co/deep-rl-course/unit0/introduction)** that gives you all the **information about the course and helps you to onboard** 🤗
#
# 🔲 📚 **Develop an understanding of the foundations of Reinforcement learning** (RL process, Rewards hypothesis...) by [reading Unit 1](https://huggingface.co/deep-rl-course/unit1/introduction).

# %% [markdown]
# ## A small recap of Deep Reinforcement Learning 📚
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# Let's do a small recap on what we learned in the first Unit:
#
# - Reinforcement Learning is a **computational approach to learning from actions**. We build an agent that learns from the environment by **interacting with it through trial and error** and receiving rewards (negative or positive) as feedback.
#
# - The goal of any RL agent is to **maximize its expected cumulative reward** (also called expected return) because RL is based on the _reward hypothesis_, which is that all goals can be described as the maximization of an expected cumulative reward.
#
# - The RL process is a **loop that outputs a sequence of state, action, reward, and next state**.
#
# - To calculate the expected cumulative reward (expected return), **we discount the rewards**: the rewards that come sooner (at the beginning of the game) are more probable to happen since they are more predictable than the long-term future reward.
#
# - To solve an RL problem, you want to **find an optimal policy**; the policy is the "brain" of your AI that will tell us what action to take given a state. The optimal one is the one that gives you the actions that max the expected return.
#
# There are **two** ways to find your optimal policy:
#
# - By **training your policy directly**: policy-based methods.
# - By **training a value function** that tells us the expected return the agent will get at each state and use this function to define our policy: value-based methods.
#
# - Finally, we spoke about Deep RL because **we introduce deep neural networks to estimate the action to take (policy-based) or to estimate the value of a state (value-based) hence the name "deep."**

# %% [markdown]
# # Let's train our first Deep Reinforcement Learning agent and upload it to the Hub 🚀
#
# ## Get a certificate 🎓
#
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
#
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Install dependencies and create a virtual screen 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones.
#
# - `gymnasium[box2d]`: Contains the LunarLander-v2 environment 🌛
# - `stable-baselines3[extra]`: The deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
#
# To make things easier, we created a script to install all these dependencies.

# %%
# !apt install swig cmake

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %%
# !apt install -y swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
# !pip install stable-baselines3[extra]>=2.0.0
# !pip install gymnasium[box2d]
# !pip install huggingface_sb3
# !pip install shimmy>=0.2.1
# Out:
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (0.36.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (6.0.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2026.1.4)

# %% [markdown]
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install virtual screen libraries and create and run a virtual screen 🖥

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (2,812 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)

# %% [markdown]
# To make sure the new installed libraries are used, **sometimes it's required to restart the notebook runtime**. The next cell will force the **runtime to crash, so you'll need to connect again and run the code starting from here**. Thanks to this trick, **we will be able to run our virtual screen.**

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Import the packages 📦
#
# One additional library we import is huggingface_hub **to be able to upload and download trained models from the hub**.
#
#
# The Hugging Face Hub 🤗 works as a central place where anyone can share and explore models and datasets. It has versioning, metrics, visualizations and other features that will allow you to easily collaborate with others.
#
# You can see here all the Deep reinforcement Learning models available here👉 https://huggingface.co/models?pipeline_tag=reinforcement-learning&sort=downloads

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Understand Gymnasium and how it works 🤖
#
# 🏋 The library containing our environment is called Gymnasium.
# **You'll use Gymnasium a lot in Deep Reinforcement Learning.**
#
# Gymnasium is the **new version of Gym library** [maintained by the Farama Foundation](https://farama.org/).
#
# The Gymnasium library provides two things:
#
# - An interface that allows you to **create RL environments**.
# - A **collection of environments** (gym-control, atari, box2D...).
#
# Let's look at an example, but first let's recall the RL loop.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/RL_process_game.jpg" alt="The RL process" width="100%">

# %% [markdown]
# At each step:
# - Our Agent receives a **state (S0)** from the **Environment** — we receive the first frame of our game (Environment).
# - Based on that **state (S0),** the Agent takes an **action (A0)** — our Agent will move to the right.
# - The environment transitions to a **new** **state (S1)** — new frame.
# - The environment gives some **reward (R1)** to the Agent — we’re not dead *(Positive Reward +1)*.
#
#
# With Gymnasium:
#
# 1️⃣ We create our environment using `gymnasium.make()`
#
# 2️⃣ We reset the environment to its initial state with `observation = env.reset()`
#
# At each step:
#
# 3️⃣ Get an action using our model (in our example we take a random action)
#
# 4️⃣ Using `env.step(action)`, we perform this action in the environment and get
# - `observation`: The new state (st+1)
# - `reward`: The reward we get after executing the action
# - `terminated`: Indicates if the episode terminated (agent reach the terminal state)
# - `truncated`: Introduced with this new version, it indicates a timelimit or if an agent go out of bounds of the environment for instance.
# - `info`: A dictionary that provides additional information (depends on the environment).
#
# For more explanations check this 👉 https://gymnasium.farama.org/api/env/#gymnasium.Env.step
#
# If the episode is terminated:
# - We reset the environment to its initial state with `observation = env.reset()`
#
# **Let's look at an example!** Make sure to read the code

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
# env = gym.make("LunarLander-v2")
# env = gym.make("LunarLander-v3")
env = gym.make("LunarLander-v3", render_mode="rgb_array")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

print("Setup complete! You are ready to train your agent.")
env.close()
# Out:
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute
# <frozen importlib._bootstrap>:488: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# Action taken: 1
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 1
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Setup complete! You are ready to train your agent.
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Create the LunarLander environment 🌛 and understand how it works
#
# ### [The environment 🎮](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
#
# In this first tutorial, we’re going to train our agent, a [Lunar Lander](https://gymnasium.farama.org/environments/box2d/lunar_lander/), **to land correctly on the moon**. To do that, the agent needs to learn **to adapt its speed and position (horizontal, vertical, and angular) to land correctly.**
#
# ---
#
#
# 💡 A good habit when you start to use an environment is to check its documentation
#
# 👉 https://gymnasium.farama.org/environments/box2d/lunar_lander/
#
# ---

# %% [markdown]
# Let's see what the Environment looks like:

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v3", render_mode="rgb_array")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-1.2249416   2.1761503   3.4059348  -9.777527    1.275462   -6.904006
#   0.5681155   0.25072587]

# %% [markdown]
# We see with `Observation Space Shape (8,)` that the observation is a vector of size 8, where each value contains different information about the lander:
# - Horizontal pad coordinate (x)
# - Vertical pad coordinate (y)
# - Horizontal speed (x)
# - Vertical speed (y)
# - Angle
# - Angular speed
# - If the left leg contact point has touched the land (boolean)
# - If the right leg contact point has touched the land (boolean)

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %% [markdown]
# The action space (the set of possible actions the agent can take) is discrete with 4 actions available 🎮:
#
# - Action 0: Do nothing,
# - Action 1: Fire left orientation engine,
# - Action 2: Fire the main engine,
# - Action 3: Fire right orientation engine.
#
# Reward function (the function that will give a reward at each timestep) 💰:
#
# After every step a reward is granted. The total reward of an episode is the **sum of the rewards for all the steps within that episode**.
#
# For each step, the reward:
#
# - Is increased/decreased the closer/further the lander is to the landing pad.
# -  Is increased/decreased the slower/faster the lander is moving.
# - Is decreased the more the lander is tilted (angle not horizontal).
# - Is increased by 10 points for each leg that is in contact with the ground.
# - Is decreased by 0.03 points each frame a side engine is firing.
# - Is decreased by 0.3 points each frame the main engine is firing.
#
# The episode receive an **additional reward of -100 or +100 points for crashing or landing safely respectively.**
#
# An episode is **considered a solution if it scores at least 200 points.**

# %% [markdown]
# #### Vectorized Environment
#
# - We create a vectorized environment (a method for stacking multiple independent environments into a single environment) of 16 environments, this way, **we'll have more diverse experiences during the training.**

# %%
# Create the environment
env = make_vec_env('LunarLander-v3', n_envs=16)

# %% [markdown]
# ## Create the Model 🤖
# - We have studied our environment and we understood the problem: **being able to land the Lunar Lander to the Landing Pad correctly by controlling left, right and main orientation engine**. Now let's build the algorithm we're going to use to solve this Problem 🚀.
#
# - To do so, we're going to use our first Deep RL library, [Stable Baselines3 (SB3)](https://stable-baselines3.readthedocs.io/en/master/).
#
# - SB3 is a set of **reliable implementations of reinforcement learning algorithms in PyTorch**.
#
# ---
#
# 💡 A good habit when using a new library is to dive first on the documentation: https://stable-baselines3.readthedocs.io/en/master/ and then try some tutorials.
#
# ----

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit1/sb3.png" alt="Stable Baselines3">

# %% [markdown]
# To solve this problem, we're going to use SB3 **PPO**. [PPO (aka Proximal Policy Optimization) is one of the SOTA (state of the art) Deep Reinforcement Learning algorithms that you'll study during this course](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#example%5D).
#
# PPO is a combination of:
# - *Value-based reinforcement learning method*: learning an action-value function that will tell us the **most valuable action to take given a state and action**.
# - *Policy-based reinforcement learning method*: learning a policy that will **give us a probability distribution over actions**.

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You **create your environment** (in our case it was done above)
#
# 2️⃣ You define the **model you want to use and instantiate this model** `model = PPO("MlpPolicy")`
#
# 3️⃣ You **train the agent** with `model.learn` and define the number of training timesteps
#
# ```
# # Create environment
# env = gym.make('LunarLander-v2')
#
# # Instantiate the agent
# model = PPO('MlpPolicy', env, verbose=1)
# # Train the agent
# model.learn(total_timesteps=int(2e5))
# ```

# %%
import os
cpu_cores = os.cpu_count()
print(f"Available CPU logical cores: {cpu_cores}")
# Out:
# Available CPU logical cores: 2

# %%
import torch

# Check if CUDA (GPU) is available
# device = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE = "cpu"
print(f"Using device: {DEVICE}")
# Out:
# Using device: cpu

# %%
# TODO: Define a PPO MlpPolicy architecture
# We use MultiLayerPerceptron (MLPPolicy) because the input is a vector,
# if we had frames as input we would use CnnPolicy
# Environment setup
n_envs = 4
env = make_vec_env("LunarLander-v3", n_envs=n_envs)
eval_env = make_vec_env("LunarLander-v3", n_envs=1)

# Linear Learning Rate Scheduler
def linear_schedule(initial_value):
    def func(progress_remaining):
        return progress_remaining * initial_value
    return func

# Instantiate the agent
model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=linear_schedule(0.0003),
    n_steps=1024,        # Steps per environment before an update
    batch_size=128,      # Minibatch size
    n_epochs=10,         # Number of optimization epochs per update
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    clip_range=0.2,
    verbose=1,
    device=DEVICE        # Ensure you are on GPU
)

callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=245, verbose=1)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./logs/",
    log_path="./logs/",
    eval_freq=max(10000 // n_envs, 1), # Account for n_envs in eval_freq
    deterministic=True,
    render=False
)

# Train the agent and display a progress bar
model.learn(total_timesteps=1500000, callback=eval_callback, progress_bar=True)
# Out:
# Using cpu device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning:
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects
# to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Output()
# /usr/local/lib/python3.12/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -138     |
# | time/              |          |
# |    fps             | 1522     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4096     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -162         |
# | time/                   |              |
# |    fps                  | 1537         |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0083061885 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00177      |
# |    learning_rate        | 0.000299     |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00576     |
# |    value_loss           | 2.57e+03     |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=-169.10 +/- 245.86
# Episode length: 300.40 +/- 351.89
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 300          |
# |    mean_reward          | -169         |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0057876566 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0155      |
# |    learning_rate        | 0.000298     |
# |    loss                 | 2.53e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00761     |
# |    value_loss           | 5.85e+03     |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -152     |
# | time/              |          |
# |    fps             | 1099     |
# |    iterations      | 3        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 12288    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.5         |
# |    ep_rew_mean          | -146         |
# | time/                   |              |
# |    fps                  | 1103         |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0041742437 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00535     |
# |    learning_rate        | 0.000298     |
# |    loss                 | 1.15e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 2.56e+03     |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=-96.24 +/- 16.21
# Episode length: 415.40 +/- 59.64
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 415         |
# |    mean_reward          | -96.2       |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.006682952 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0267      |
# |    learning_rate        | 0.000297    |
# |    loss                 | 775         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 105      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    fps             | 1007     |
# |    iterations      | 5        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 6           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011628507 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00537     |
# |    learning_rate        | 0.000296    |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 2.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 1105        |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009649968 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.00223    |
# |    learning_rate        | 0.000295    |
# |    loss                 | 587         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=-3854.51 +/- 2256.26
# Episode length: 535.20 +/- 154.75
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 535        |
# |    mean_reward          | -3.85e+03  |
# | time/                   |            |
# |    total_timesteps      | 30000      |
# | train/                  |            |
# |    approx_kl            | 0.00897461 |
# |    clip_fraction        | 0.0832     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.0143    |
# |    learning_rate        | 0.000294   |
# |    loss                 | 833        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00989   |
# |    value_loss           | 1.7e+03    |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    fps             | 1003     |
# |    iterations      | 8        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 9           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008681332 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.00015    |
# |    learning_rate        | 0.000293    |
# |    loss                 | 246         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 756         |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=-268.29 +/- 14.38
# Episode length: 329.40 +/- 108.82
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 329         |
# |    mean_reward          | -268        |
# | time/                   |             |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.007116193 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000515   |
# |    learning_rate        | 0.000293    |
# |    loss                 | 468         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 787         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -93.6    |
# | time/              |          |
# |    fps             | 1020     |
# |    iterations      | 10       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 40960    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | -80.2       |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008371266 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.00114     |
# |    learning_rate        | 0.000292    |
# |    loss                 | 231         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 673         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -71         |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 12          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007805973 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.00418    |
# |    learning_rate        | 0.000291    |
# |    loss                 | 240         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0062     |
# |    value_loss           | 516         |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=-189.37 +/- 34.39
# Episode length: 296.40 +/- 148.76
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 296         |
# |    mean_reward          | -189        |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.008796363 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.00344    |
# |    learning_rate        | 0.00029     |
# |    loss                 | 256         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 425         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | -64.2    |
# | time/              |          |
# |    fps             | 1037     |
# |    iterations      | 13       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -50.8       |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 14          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010589755 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.00193     |
# |    learning_rate        | 0.000289    |
# |    loss                 | 177         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 376         |
# -----------------------------------------
# Eval num_timesteps=60000, episode_reward=-194.64 +/- 29.36
# Episode length: 459.00 +/- 234.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 459          |
# |    mean_reward          | -195         |
# | time/                   |              |
# |    total_timesteps      | 60000        |
# | train/                  |              |
# |    approx_kl            | 0.0032590528 |
# |    clip_fraction        | 0.00569      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -0.0275      |
# |    learning_rate        | 0.000289     |
# |    loss                 | 279          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 767          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | -42.8    |
# | time/              |          |
# |    fps             | 977      |
# |    iterations      | 15       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 61440    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 16          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005345207 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0101      |
# |    learning_rate        | 0.000288    |
# |    loss                 | 198         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 489         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 974          |
# |    iterations           | 17           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0047077388 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.000287     |
# |    loss                 | 192          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 399          |
# ------------------------------------------
# Eval num_timesteps=70000, episode_reward=-125.85 +/- 39.24
# Episode length: 361.60 +/- 53.06
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 362          |
# |    mean_reward          | -126         |
# | time/                   |              |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0035035885 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.317        |
# |    learning_rate        | 0.000286     |
# |    loss                 | 181          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 349          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 181      |
# |    ep_rew_mean     | -8.64    |
# | time/              |          |
# |    fps             | 954      |
# |    iterations      | 18       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 73728    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | -10.5       |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 19          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007875394 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.379       |
# |    learning_rate        | 0.000285    |
# |    loss                 | 162         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 478         |
# -----------------------------------------
# Eval num_timesteps=80000, episode_reward=-172.04 +/- 57.71
# Episode length: 366.00 +/- 91.55
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 366          |
# |    mean_reward          | -172         |
# | time/                   |              |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 0.0045192474 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.415        |
# |    learning_rate        | 0.000284     |
# |    loss                 | 310          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 554          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -9.65    |
# | time/              |          |
# |    fps             | 895      |
# |    iterations      | 20       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 81920    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | -11.5       |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 21          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006323306 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.000284    |
# |    loss                 | 124         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 281         |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=-110.63 +/- 18.29
# Episode length: 881.20 +/- 237.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 881         |
# |    mean_reward          | -111        |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.007156497 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.000283    |
# |    loss                 | 175         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 424         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 231      |
# |    ep_rew_mean     | -8.8     |
# | time/              |          |
# |    fps             | 806      |
# |    iterations      | 22       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 90112    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | -5.75       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 23          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004371539 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.000282    |
# |    loss                 | 105         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 223         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | -7.67        |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 24           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0064867777 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.000281     |
# |    loss                 | 71.5         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 176          |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=-172.45 +/- 64.30
# Episode length: 412.60 +/- 135.51
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 413          |
# |    mean_reward          | -172         |
# | time/                   |              |
# |    total_timesteps      | 100000       |
# | train/                  |              |
# |    approx_kl            | 0.0056013167 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.00028      |
# |    loss                 | 114          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 392          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 323      |
# |    ep_rew_mean     | -6.84    |
# | time/              |          |
# |    fps             | 757      |
# |    iterations      | 25       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 102400   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | -5.36        |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 26           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0061169574 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.00028      |
# |    loss                 | 93.2         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 204          |
# ------------------------------------------
# Eval num_timesteps=110000, episode_reward=-190.91 +/- 41.89
# Episode length: 606.40 +/- 178.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 606         |
# |    mean_reward          | -191        |
# | time/                   |             |
# |    total_timesteps      | 110000      |
# | train/                  |             |
# |    approx_kl            | 0.005901894 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.000279    |
# |    loss                 | 107         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 243         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | -7.31    |
# | time/              |          |
# |    fps             | 725      |
# |    iterations      | 27       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 110592   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | -2.09        |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 28           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0045797573 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 0.000278     |
# |    loss                 | 74.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 316          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | -0.107       |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 29           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0112800505 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.000277     |
# |    loss                 | 49           |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 144          |
# ------------------------------------------
# Eval num_timesteps=120000, episode_reward=-58.43 +/- 34.80
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -58.4       |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.007832885 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.000276    |
# |    loss                 | 79.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 113         |
# -----------------------------------------
# New best mean reward!
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | 6.73        |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 31          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006648003 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 54.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 151         |
# -----------------------------------------
# Eval num_timesteps=130000, episode_reward=-46.94 +/- 30.08
# Episode length: 604.80 +/- 328.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 605         |
# |    mean_reward          | -46.9       |
# | time/                   |             |
# |    total_timesteps      | 130000      |
# | train/                  |             |
# |    approx_kl            | 0.005924049 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.000275    |
# |    loss                 | 37.8        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 117         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 526      |
# |    ep_rew_mean     | 13.3     |
# | time/              |          |
# |    fps             | 656      |
# |    iterations      | 32       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 131072   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 654         |
# |    iterations           | 33          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.008750206 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.000274    |
# |    loss                 | 34.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 84.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 563         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 34          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.006942611 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.000273    |
# |    loss                 | 46.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 91.7        |
# -----------------------------------------
# Eval num_timesteps=140000, episode_reward=-48.98 +/- 39.35
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -49          |
# | time/                   |              |
# |    total_timesteps      | 140000       |
# | train/                  |              |
# |    approx_kl            | 0.0072286264 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.000272     |
# |    loss                 | 26           |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 36.3         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 597      |
# |    ep_rew_mean     | 24.7     |
# | time/              |          |
# |    fps             | 619      |
# |    iterations      | 35       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 143360   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 638         |
# |    ep_rew_mean          | 30.4        |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 36          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.004519524 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.000271    |
# |    loss                 | 29.3        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 57.2        |
# -----------------------------------------
# Eval num_timesteps=150000, episode_reward=-37.13 +/- 17.35
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -37.1        |
# | time/                   |              |
# |    total_timesteps      | 150000       |
# | train/                  |              |
# |    approx_kl            | 0.0038732816 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.000271     |
# |    loss                 | 11.8         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 39           |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 657      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    fps             | 593      |
# |    iterations      | 37       |
# |    time_elapsed    | 255      |
# |    total_timesteps | 151552   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 674          |
# |    ep_rew_mean          | 34.1         |
# | time/                   |              |
# |    fps                  | 594          |
# |    iterations           | 38           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0052817906 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.00027      |
# |    loss                 | 19.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 85           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | 37.5        |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 39          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.008349543 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.000269    |
# |    loss                 | 27.3        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 58.3        |
# -----------------------------------------
# Eval num_timesteps=160000, episode_reward=-52.96 +/- 31.23
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -53         |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.007758824 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.000268    |
# |    loss                 | 11.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 47.2        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 706      |
# |    ep_rew_mean     | 39.9     |
# | time/              |          |
# |    fps             | 567      |
# |    iterations      | 40       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 163840   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | 43.9        |
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 41          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.004567271 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.000267    |
# |    loss                 | 15.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 51.5        |
# -----------------------------------------
# Eval num_timesteps=170000, episode_reward=-19.48 +/- 54.91
# Episode length: 968.40 +/- 63.20
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 968          |
# |    mean_reward          | -19.5        |
# | time/                   |              |
# |    total_timesteps      | 170000       |
# | train/                  |              |
# |    approx_kl            | 0.0048454115 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.000266     |
# |    loss                 | 47.4         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 124          |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 741      |
# |    ep_rew_mean     | 49.6     |
# | time/              |          |
# |    fps             | 550      |
# |    iterations      | 42       |
# |    time_elapsed    | 312      |
# |    total_timesteps | 172032   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 57.3        |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 43          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008939385 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.000266    |
# |    loss                 | 13.5        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 41.8        |
# -----------------------------------------
# Eval num_timesteps=180000, episode_reward=36.48 +/- 122.62
# Episode length: 845.00 +/- 153.01
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 845       |
# |    mean_reward          | 36.5      |
# | time/                   |           |
# |    total_timesteps      | 180000    |
# | train/                  |           |
# |    approx_kl            | 0.0087792 |
# |    clip_fraction        | 0.0666    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.08     |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.000265  |
# |    loss                 | 13.6      |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.00467  |
# |    value_loss           | 33.3      |
# ---------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 774      |
# |    ep_rew_mean     | 62.5     |
# | time/              |          |
# |    fps             | 537      |
# |    iterations      | 44       |
# |    time_elapsed    | 335      |
# |    total_timesteps | 180224   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 66.6         |
# | time/                   |              |
# |    fps                  | 537          |
# |    iterations           | 45           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0058127353 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.000264     |
# |    loss                 | 50           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 53.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 799        |
# |    ep_rew_mean          | 69.8       |
# | time/                   |            |
# |    fps                  | 537        |
# |    iterations           | 46         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00625413 |
# |    clip_fraction        | 0.0303     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.000263   |
# |    loss                 | 16.2       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00307   |
# |    value_loss           | 33.6       |
# ----------------------------------------
# Eval num_timesteps=190000, episode_reward=73.33 +/- 143.92
# Episode length: 575.00 +/- 224.59
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 575         |
# |    mean_reward          | 73.3        |
# | time/                   |             |
# |    total_timesteps      | 190000      |
# | train/                  |             |
# |    approx_kl            | 0.007836475 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.000262    |
# |    loss                 | 89          |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 132         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    fps             | 533      |
# |    iterations      | 47       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 192512   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 792         |
# |    ep_rew_mean          | 73.3        |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 48          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.006340545 |
# |    clip_fraction        | 0.0124      |
# |    clip_range           | 0.2         |
# ...
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 259      |
# | time/              |          |
# |    fps             | 734      |
# |    iterations      | 352      |
# |    time_elapsed    | 1962     |
# |    total_timesteps | 1441792  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 248           |
# |    ep_rew_mean          | 254           |
# | time/                   |               |
# |    fps                  | 735           |
# |    iterations           | 353           |
# |    time_elapsed         | 1965          |
# |    total_timesteps      | 1445888       |
# | train/                  |               |
# |    approx_kl            | 9.8518634e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.599        |
# |    explained_variance   | 0.917         |
# |    learning_rate        | 1.16e-05      |
# |    loss                 | 278           |
# |    n_updates            | 3520          |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 239           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 247          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 354          |
# |    time_elapsed         | 1968         |
# |    total_timesteps      | 1449984      |
# | train/                  |              |
# |    approx_kl            | 0.0023630066 |
# |    clip_fraction        | 0.000659     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 1.08e-05     |
# |    loss                 | 163          |
# |    n_updates            | 3530         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 619          |
# ------------------------------------------
# Eval num_timesteps=1450000, episode_reward=266.67 +/- 18.21
# Episode length: 245.60 +/- 17.87
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 246         |
# |    mean_reward          | 267         |
# | time/                   |             |
# |    total_timesteps      | 1450000     |
# | train/                  |             |
# |    approx_kl            | 0.002239816 |
# |    clip_fraction        | 0.00605     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 20.9        |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 31          |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 245      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    fps             | 737      |
# |    iterations      | 355      |
# |    time_elapsed    | 1972     |
# |    total_timesteps | 1454080  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 356          |
# |    time_elapsed         | 1976         |
# |    total_timesteps      | 1458176      |
# | train/                  |              |
# |    approx_kl            | 8.681732e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 9.18e-06     |
# |    loss                 | 409          |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 433          |
# ------------------------------------------
# Eval num_timesteps=1460000, episode_reward=269.89 +/- 23.88
# Episode length: 253.20 +/- 20.34
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 253          |
# |    mean_reward          | 270          |
# | time/                   |              |
# |    total_timesteps      | 1460000      |
# | train/                  |              |
# |    approx_kl            | 5.804497e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 8.36e-06     |
# |    loss                 | 293          |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -5.12e-05    |
# |    value_loss           | 548          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    fps             | 738      |
# |    iterations      | 357      |
# |    time_elapsed    | 1980     |
# |    total_timesteps | 1462272  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 260           |
# |    ep_rew_mean          | 250           |
# | time/                   |               |
# |    fps                  | 739           |
# |    iterations           | 358           |
# |    time_elapsed         | 1983          |
# |    total_timesteps      | 1466368       |
# | train/                  |               |
# |    approx_kl            | 1.1356693e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.65         |
# |    explained_variance   | 0.93          |
# |    learning_rate        | 7.55e-06      |
# |    loss                 | 146           |
# |    n_updates            | 3570          |
# |    policy_gradient_loss | -5.09e-05     |
# |    value_loss           | 280           |
# -------------------------------------------
# Eval num_timesteps=1470000, episode_reward=277.81 +/- 20.22
# Episode length: 225.00 +/- 34.11
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 225           |
# |    mean_reward          | 278           |
# | time/                   |               |
# |    total_timesteps      | 1470000       |
# | train/                  |               |
# |    approx_kl            | 0.00018433077 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.596        |
# |    explained_variance   | 0.861         |
# |    learning_rate        | 6.73e-06      |
# |    loss                 | 288           |
# |    n_updates            | 3580          |
# |    policy_gradient_loss | -0.000865     |
# |    value_loss           | 415           |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | 251      |
# | time/              |          |
# |    fps             | 739      |
# |    iterations      | 359      |
# |    time_elapsed    | 1988     |
# |    total_timesteps | 1470464  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 273           |
# |    ep_rew_mean          | 251           |
# | time/                   |               |
# |    fps                  | 739           |
# |    iterations           | 360           |
# |    time_elapsed         | 1992          |
# |    total_timesteps      | 1474560       |
# | train/                  |               |
# |    approx_kl            | 0.00033859193 |
# |    clip_fraction        | 2.44e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.624        |
# |    explained_variance   | 0.931         |
# |    learning_rate        | 5.91e-06      |
# |    loss                 | 167           |
# |    n_updates            | 3590          |
# |    policy_gradient_loss | -0.000632     |
# |    value_loss           | 315           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 361          |
# |    time_elapsed         | 1996         |
# |    total_timesteps      | 1478656      |
# | train/                  |              |
# |    approx_kl            | 7.104606e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 5.09e-06     |
# |    loss                 | 136          |
# |    n_updates            | 3600         |
# |    policy_gradient_loss | -0.000356    |
# |    value_loss           | 397          |
# ------------------------------------------
# Eval num_timesteps=1480000, episode_reward=265.24 +/- 13.99
# Episode length: 251.60 +/- 20.32
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 252          |
# |    mean_reward          | 265          |
# | time/                   |              |
# |    total_timesteps      | 1480000      |
# | train/                  |              |
# |    approx_kl            | 0.0012161091 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 4.27e-06     |
# |    loss                 | 58.6         |
# |    n_updates            | 3610         |
# |    policy_gradient_loss | -0.000923    |
# |    value_loss           | 295          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 261      |
# |    ep_rew_mean     | 249      |
# | time/              |          |
# |    fps             | 740      |
# |    iterations      | 362      |
# |    time_elapsed    | 2002     |
# |    total_timesteps | 1482752  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 285          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 363          |
# |    time_elapsed         | 2006         |
# |    total_timesteps      | 1486848      |
# | train/                  |              |
# |    approx_kl            | 2.554807e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 3.45e-06     |
# |    loss                 | 275          |
# |    n_updates            | 3620         |
# |    policy_gradient_loss | -4.15e-05    |
# |    value_loss           | 465          |
# ------------------------------------------
# Eval num_timesteps=1490000, episode_reward=275.17 +/- 21.41
# Episode length: 242.40 +/- 15.67
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 242          |
# |    mean_reward          | 275          |
# | time/                   |              |
# |    total_timesteps      | 1490000      |
# | train/                  |              |
# |    approx_kl            | 1.583749e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 2.63e-06     |
# |    loss                 | 133          |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -7.91e-05    |
# |    value_loss           | 309          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    fps             | 740      |
# |    iterations      | 364      |
# |    time_elapsed    | 2013     |
# |    total_timesteps | 1490944  |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 302           |
# |    ep_rew_mean          | 250           |
# | time/                   |               |
# |    fps                  | 741           |
# |    iterations           | 365           |
# |    time_elapsed         | 2017          |
# |    total_timesteps      | 1495040       |
# | train/                  |               |
# |    approx_kl            | 1.2822071e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.583        |
# |    explained_variance   | 0.949         |
# |    learning_rate        | 1.81e-06      |
# |    loss                 | 118           |
# |    n_updates            | 3640          |
# |    policy_gradient_loss | -6.87e-05     |
# |    value_loss           | 345           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 366          |
# |    time_elapsed         | 2020         |
# |    total_timesteps      | 1499136      |
# | train/                  |              |
# |    approx_kl            | 1.128341e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 9.92e-07     |
# |    loss                 | 48           |
# |    n_updates            | 3650         |
# |    policy_gradient_loss | -1.93e-05    |
# |    value_loss           | 76.2         |
# ------------------------------------------
# Eval num_timesteps=1500000, episode_reward=287.38 +/- 23.30
# Episode length: 240.40 +/- 17.19
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 240           |
# |    mean_reward          | 287           |
# | time/                   |               |
# |    total_timesteps      | 1500000       |
# | train/                  |               |
# |    approx_kl            | 3.7267455e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.58         |
# |    explained_variance   | 0.846         |
# |    learning_rate        | 1.73e-07      |
# |    loss                 | 143           |
# |    n_updates            | 3660          |
# |    policy_gradient_loss | -7.77e-06     |
# |    value_loss           | 544           |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    fps             | 741      |
# |    iterations      | 367      |
# |    time_elapsed    | 2026     |
# |    total_timesteps | 1503232  |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Train the PPO agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~20min, but you can use fewer timesteps if you just want to try it out.
# - During the training, take a ☕ break you deserved it 🤗

# %%
# TODO: Train it for 1,000,000 timesteps

# TODO: Specify file name for model and save the model to file
model_name = "ppo-LunarLander-v3-opt"
model.save(model_name)

# %% [markdown]
# ## Evaluate the agent 📈
# - Remember to wrap the environment in a [Monitor](https://stable-baselines3.readthedocs.io/en/master/common/monitor.html).
# - Now that our Lunar Lander agent is trained 🚀, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`.
# - To fill that part you need to [check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/examples.html#basic-usage-training-saving-loading)
# - In the next step,  we'll see **how to automatically evaluate and share your agent to compete in a leaderboard, but for now let's do it ourselves**
#
#
# 💡 When you evaluate your agent, you should not use your training environment but create an evaluation environment.

# %%
# TODO: Evaluate the agent
# Create a new environment for evaluation
eval_env = gym.make("LunarLander-v3", render_mode="rgb_array")
eval_env = Monitor(eval_env)

# Evaluate the model with 10 evaluation episodes and deterministic=True
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True
)

# Print the results
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward}")
# Out:
# Mean reward: 270.85 +/- 17.48909068906193

# %% [markdown]
# ## Publish our trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20
#
# Here's an example of a Model Card (with Space Invaders):

# %% [markdown]
# By using `package_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account on Hugging Face ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# # from huggingface_hub import login

# # # Replace 'your_new_write_token_here' with your actual token
# # login(token='', add_to_git_credential=True)

# import os
# from huggingface_hub import HfApi, login

# # 1. Manually delete the local token file if it exists
# token_path = os.path.expanduser("~/.cache/huggingface/token")
# if os.path.exists(token_path):
#     os.remove(token_path)
#     print("🗑️ Old cached token deleted.")

# # Replace with your actual WRITE token
# MY_TOKEN = ""

# # Force login
# login(token=MY_TOKEN, add_to_git_credential=True)

# # 2. Verify identity and permissions
# api = HfApi()
# user_info = api.whoami()
# print(f"✅ Successfully logged in as: {user_info['name']}")
# print(f"✅ Token has Write access: {user_info['auth']['type'] == 'WRITE'}")

# %%
from huggingface_hub import HfApi
api = HfApi()
print(api.whoami())
# Out:
# {'type': 'user', 'id': '638faa7f21d355ca70d54e38', 'name': 'Chiz', 'fullname': 'Chizoba Obasi', 'isPro': False, 'avatarUrl': '/avatars/ff996ad197af22f876fff1dddd29077e.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'Colab-ppo-LunarLander-v3', 'role': 'fineGrained', 'createdAt': '2026-01-12T23:59:31.890Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '638faa7f21d355ca70d54e38', 'type': 'user', 'name': 'Chiz'}, 'permissions': ['collection.read', 'repo.content.read', 'repo.write', 'collection.write']}]}}}}
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# Let's fill the `package_to_hub` function:
# - `model`: our trained model.
# - `model_name`: the name of the trained model that we defined in `model_save`
# - `model_architecture`: the model architecture we used, in our case PPO
# - `env_id`: the name of the environment, in our case `LunarLander-v2`
# - `eval_env`: the evaluation environment defined in eval_env
# - `repo_id`: the name of the Hugging Face Hub Repository that will be created/updated `(repo_id = {username}/{repo_name})`
#
# 💡 **A good name is {username}/{model_architecture}-{env_id}**
#
# - `commit_message`: message of the commit

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id = "Chiz/ppo-LunarLander-v3"

# TODO: Define the name of the environment
env_id = "LunarLander-v3"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))])

# eval_env = VecVideoRecorder(
#     eval_env,
#     video_folder="./videos",
#     record_video_trigger=lambda step: step == 0,
#     video_length=1000,
#     name_prefix="ppo-lunarlander"
# )

# TODO: Define the model architecture we used
model_architecture = "PPO"

## TODO: Define the commit message
commit_message = "Upload 1st successful moon landing of PPO LunarLander-v3 trained agent"

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpgyw8ayre/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmpgyw8ayre/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpgyw8ayre/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpgyw8ayre/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo Chiz/ppo-LunarLander-v3 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...opt/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   ...-opt/policy.optimizer.pth: 100%|##########| 88.4kB / 88.4kB
#   ...rLander-v3-opt/policy.pth: 100%|##########| 44.0kB / 44.0kB
#   ...po-LunarLander-v3-opt.zip: 100%|##########|  151kB /  151kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Chiz/ppo-LunarLander-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Chiz/ppo-LunarLander-v3/commit/4b16965e49602823315672301b02d68b730498ad', commit_message='Upload 1st successful moon landing of PPO LunarLander-v3 trained agent', commit_description='', oid='4b16965e49602823315672301b02d68b730498ad', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Chiz/ppo-LunarLander-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='Chiz/ppo-LunarLander-v3'), pr_revision=None, pr_num=None)

# %%
from stable_baselines3 import PPO
from huggingface_sb3 import package_to_hub
import gymnasium as gym

# 1. Define the parameters
model_name = "ppo-LunarLander-v3"
model_architecture = "PPO"
env_id = "LunarLander-v3"
repo_id = "Chiz/ppo-LunarLander-v3" # Replace with your actual HF username if different
commit_message = "Upload optimized PPO LunarLander-v3 agent with score > 250"

# 2. Load the best model saved by the EvalCallback
# The callback saves it as 'best_model.zip' in the path you specified
best_model_path = "./logs/best_model.zip"
model = PPO.load(best_model_path, env=env)

# 3. Create a clean evaluation environment
# package_to_hub needs this to verify the score one last time
eval_env = gym.make(env_id, render_mode="rgb_array")

# 4. Package and Push
# This will:
# - Evaluate the model for 10 episodes
# - Record a video of the agent playing
# - Generate a model card with your hyperparameters
# - Push everything to the Hugging Face Hub
package_to_hub(
    model=model,
    model_name=model_name,
    model_architecture=model_architecture,
    env_id=env_id,
    eval_env=eval_env,
    repo_id=repo_id,
    commit_message=commit_message
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmp62adfpr5/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp62adfpr5/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp62adfpr5/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp62adfpr5/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo Chiz/ppo-LunarLander-v3 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...-v3/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   ...r-v3/policy.optimizer.pth: 100%|##########| 88.4kB / 88.4kB
#   ...LunarLander-v3/policy.pth: 100%|##########| 44.0kB / 44.0kB
#   ...LunarLander-v3/policy.pth: 100%|##########| 44.0kB / 44.0kB
#   ...xb/ppo-LunarLander-v3.zip: 100%|##########|  150kB /  150kB
#   ...xb/ppo-LunarLander-v3.zip: 100%|##########|  150kB /  150kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Chiz/ppo-LunarLander-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Chiz/ppo-LunarLander-v3/commit/4dee190887b77be4b7958391d22b6ed5596d046d', commit_message='Upload optimized PPO LunarLander-v3 agent with score > 250', commit_description='', oid='4dee190887b77be4b7958391d22b6ed5596d046d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Chiz/ppo-LunarLander-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='Chiz/ppo-LunarLander-v3'), pr_revision=None, pr_num=None)

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Reinforcement Learning agent. The script above should have displayed a link to a model repository such as https://huggingface.co/osanseviero/test_sb3. When you go to this link, you can:
# * See a video preview of your agent at the right.
# * Click "Files and versions" to see all the files in the repository.
# * Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# * A model card (`README.md` file) which gives a description of the model
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# Compare the results of your LunarLander-v2 with your classmates using the leaderboard 🏆 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %%
from gymnasium.wrappers import RecordVideo
import gymnasium as gym

env = gym.make("LunarLander-v3", render_mode="rgb_array")
env = RecordVideo(env, "./videos", name_prefix="ppo-lunarlander")

obs = env.reset()[0]
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, _ = env.step(action)
    done = terminated or truncated

env.close()

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="./videos/ppo-lunarlander-episode-0.mp4",
    path_in_repo="replay.mp4",
    repo_id="Chiz/ppo-LunarLander-v3",
    repo_type="model"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Chiz/ppo-LunarLander-v3/commit/afbd80bac2ab91dff8e47086c3001ac3cdab2625', commit_message='Upload replay.mp4 with huggingface_hub', commit_description='', oid='afbd80bac2ab91dff8e47086c3001ac3cdab2625', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Chiz/ppo-LunarLander-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='Chiz/ppo-LunarLander-v3'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Load a saved LunarLander model from the Hub 🤗
# Thanks to [ironbar](https://github.com/ironbar) for the contribution.
#
# Loading a saved model from the Hub is really easy.
#
# You go to https://huggingface.co/models?library=stable-baselines3 to see the list of all the Stable-baselines3 saved models.
# 1. You select one and copy its repo_id
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/copy-id.png" alt="Copy-id"/>

# %% [markdown]
# 2. Then we just need to use load_from_hub with:
# - The repo_id
# - The filename: the saved model inside the repo and its extension (*.zip)

# %% [markdown]
# Because the model I download from the Hub was trained with Gym (the former version of Gymnasium) we need to install shimmy a API conversion tool that will help us to run the environment correctly.
#
# Shimmy Documentation: https://github.com/Farama-Foundation/Shimmy

# %%
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)

# %% [markdown]
# Let's evaluate this agent:

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v3"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! As you saw, the current agent is not doing great. As a first suggestion, you can train for more steps. With 1,000,000 steps, we saw some great results!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters for `PPO`. You can see them at https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters.
# * Check the [Stable-Baselines3 documentation](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) and try another model such as DQN.
# * **Push your new trained model** on the Hub 🔥
#
# **Compare the results of your LunarLander-v2 with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆
#
# Is moon landing too boring for you? Try to **change the environment**, why not use MountainCar-v0, CartPole-v1 or CarRacing-v0? Check how they work [using the gym documentation](https://www.gymlibrary.dev/) and have fun 🎉.

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter! That was the biggest one, **and there was a lot of information.**
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and have a solid foundations.
#
# Naturally, during the course, we’re going to dive deeper into these concepts but **it’s better to have a good understanding of them now before diving into the next chapters.**

# %% [markdown]
# Next time, in the bonus unit 1, you'll train Huggy the Dog to fetch the stick.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit1/huggy.jpg" alt="Huggy"/>
#
# ## Keep learning, stay awesome 🤗
