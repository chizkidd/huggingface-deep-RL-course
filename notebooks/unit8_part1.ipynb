# %% [markdown]
# <a href="https://colab.research.google.com/github/chizkidd/huggingface-deep-RL-course/blob/main/notebooks/unit8/unit8_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 8: Proximal Policy Gradient (PPO) with PyTorch 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/thumbnail.png" alt="Unit 8"/>
#
#
# In this notebook, you'll learn to **code your PPO agent from scratch with PyTorch using CleanRL implementation as model**.
#
# To test its robustness, we're going to train it in:
#
# - [LunarLander-v2 🚀](https://www.gymlibrary.dev/environments/box2d/lunar_lander/)

# %% [markdown]
# ⬇️ Here is an example of what you will achieve. ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to **code your PPO agent from scratch using PyTorch**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [PPO by reading Unit 8](https://huggingface.co/deep-rl-course/unit8/introduction) 🤗

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push one model, we don't ask for a minimal result but we **advise you to try different hyperparameters settings to get better results**.
#
# If you don't find your model, **go to the bottom of the page and click on the refresh button**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the libraries and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !apt install swig cmake
# !pip install pyglet==1.5
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Install dependencies 🔽
# For this exercise, we use `gym==0.22`.

# %%
# !pip install gym==0.22
# !pip install imageio-ffmpeg
# !pip install huggingface_hub
# !pip install gym[box2d]==0.22
# Out:
# Collecting gym==0.22
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 15.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.22) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.22) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym==0.22) (0.1.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.22.0-py3-none-any.whl size=708475 sha256=f01942d49b98d5e94a44e7a608ba251859faaeb5a980880c3447a3702c9fc35c
#   Stored in directory: /root/.cache/pip/wheels/fd/bd/03/a325acb1df8746ce0573ffdf8730f4e7d32f4aa839a56f1b2f
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.22.0
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.23.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: typer>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.23.0->typer-slim->huggingface_hub) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.23.0->typer-slim->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.23.0->typer-slim->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface_hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface_hub) (0.1.2)
# Requirement already satisfied: gym==0.22 in /usr/local/lib/python3.12/dist-packages (from gym[box2d]==0.22) (0.22.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.22->gym[box2d]==0.22) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym==0.22->gym[box2d]==0.22) (3.1.2)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym==0.22->gym[box2d]==0.22) (0.1.0)
# Collecting box2d-py==2.3.5 (from gym[box2d]==0.22)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d]==0.22)
#   Downloading pygame-2.1.0.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 109.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# ## Let's code PPO from scratch with Costa Huang tutorial
# - For the core implementation of PPO we're going to use the excellent [Costa Huang](https://costa.sh/) tutorial.
# - In addition to the tutorial, to go deeper you can read the 37 core implementation details: https://iclr-blog-track.github.io/2022/03/25/ppo-implementation-details/
#
# 👉 The video tutorial: https://youtu.be/MEt6rrxH8W4

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/MEt6rrxH8W4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/MEt6rrxH8W4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# - The best is to code first on the cell below, this way, if you kill the machine **you don't loose the implementation**.

# %%
### Your code here:

# %% [markdown]
# ## Add the Hugging Face Integration 🤗
# - In order to push our model to the Hub, we need to define a function `package_to_hub`

# %% [markdown]
# - Add dependencies we need to push our model to the Hub

# %%
from huggingface_hub import HfApi, upload_folder
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio

from wasabi import Printer
msg = Printer()

# %% [markdown]
# - Add new argument in `parse_args()` function to define the repo-id where we want to push the model.

# %%
# Adding HuggingFace argument
parser.add_argument("--repo-id", type=str, default="ThomasSimonini/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")

# %% [markdown]
# - Next, we add the methods needed to push the model to the Hub
#
# - These methods will:
#   - `_evalutate_agent()`: evaluate the agent.
#   - `_generate_model_card()`: generate the model card of your agent.
#   - `_record_video()`: record a video of your agent.

# %%
def package_to_hub(repo_id,
                model,
                hyperparameters,
                eval_env,
                video_fps=30,
                commit_message="Push agent to the Hub",
                token= None,
                logs=None
                ):
  """
  Evaluate, Generate a video and Upload a model to Hugging Face Hub.
  This method does the complete pipeline:
  - It evaluates the model
  - It generates the model card
  - It generates a replay video of the agent
  - It pushes everything to the hub
  :param repo_id: id of the model repository from the Hugging Face Hub
  :param model: trained model
  :param eval_env: environment used to evaluate the agent
  :param fps: number of fps for rendering the video
  :param commit_message: commit message
  :param logs: directory on local machine of tensorboard logs you'd like to upload
  """
  msg.info(
        "This function will save, evaluate, generate a video of your agent, "
        "create a model card and push everything to the hub. "
        "It might take up to 1min. \n "
        "This is a work in progress: if you encounter a bug, please open an issue."
    )
  # Step 1: Clone or create the repo
  repo_url = HfApi().create_repo(
        repo_id=repo_id,
        token=token,
        private=False,
        exist_ok=True,
    )

  with tempfile.TemporaryDirectory() as tmpdirname:
    tmpdirname = Path(tmpdirname)

    # Step 2: Save the model
    torch.save(model.state_dict(), tmpdirname / "model.pt")

    # Step 3: Evaluate the model and build JSON
    mean_reward, std_reward = _evaluate_agent(eval_env,
                                           10,
                                           model)

    # First get datetime
    eval_datetime = datetime.datetime.now()
    eval_form_datetime = eval_datetime.isoformat()

    evaluate_data = {
        "env_id": hyperparameters.env_id,
        "mean_reward": mean_reward,
        "std_reward": std_reward,
        "n_evaluation_episodes": 10,
        "eval_datetime": eval_form_datetime,
    }

    # Write a JSON file
    with open(tmpdirname / "results.json", "w") as outfile:
      json.dump(evaluate_data, outfile)

    # Step 4: Generate a video
    video_path =  tmpdirname / "replay.mp4"
    record_video(eval_env, model, video_path, video_fps)

    # Step 5: Generate the model card
    generated_model_card, metadata = _generate_model_card("PPO", hyperparameters.env_id, mean_reward, std_reward, hyperparameters)
    _save_model_card(tmpdirname, generated_model_card, metadata)

    # Step 6: Add logs if needed
    if logs:
      _add_logdir(tmpdirname, Path(logs))

    msg.info(f"Pushing repo {repo_id} to the Hugging Face Hub")

    repo_url = upload_folder(
            repo_id=repo_id,
            folder_path=tmpdirname,
            path_in_repo="",
            commit_message=commit_message,
            token=token,
        )

    msg.info(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
  return repo_url


def _evaluate_agent(env, n_eval_episodes, policy):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param policy: The agent
  """
  episode_rewards = []
  for episode in range(n_eval_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards_ep = 0

    while done is False:
      state = torch.Tensor(state).to(device)
      action, _, _, _ = policy.get_action_and_value(state)
      new_state, reward, done, info = env.step(action.cpu().numpy())
      total_rewards_ep += reward
      if done:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward


def record_video(env, policy, out_directory, fps=30):
  images = []
  done = False
  state = env.reset()
  img = env.render(mode='rgb_array')
  images.append(img)
  while not done:
    state = torch.Tensor(state).to(device)
    # Take the action (index) that have the maximum expected future reward given that state
    action, _, _, _  = policy.get_action_and_value(state)
    state, reward, done, info = env.step(action.cpu().numpy()) # We directly put next_state = state for recording logic
    img = env.render(mode='rgb_array')
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)


def _generate_model_card(model_name, env_id, mean_reward, std_reward, hyperparameters):
  """
  Generate the model card for the Hub
  :param model_name: name of the model
  :env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  :hyperparameters: training arguments
  """
  # Step 1: Select the tags
  metadata = generate_metadata(model_name, env_id, mean_reward, std_reward)

  # Transform the hyperparams namespace to string
  converted_dict = vars(hyperparameters)
  converted_str = str(converted_dict)
  converted_str = converted_str.split(", ")
  converted_str = '\n'.join(converted_str)

  # Step 2: Generate the model card
  model_card = f"""
  # PPO Agent Playing {env_id}

  This is a trained model of a PPO agent playing {env_id}.

  # Hyperparameters
  ```python
  {converted_str}
  ```
  """
  return model_card, metadata


def generate_metadata(model_name, env_id, mean_reward, std_reward):
  """
  Define the tags for the model card
  :param model_name: name of the model
  :param env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  """
  metadata = {}
  metadata["tags"] = [
        env_id,
        "ppo",
        "deep-reinforcement-learning",
        "reinforcement-learning",
        "custom-implementation",
        "deep-rl-course"
  ]

  # Add metrics
  eval = metadata_eval_result(
      model_pretty_name=model_name,
      task_pretty_name="reinforcement-learning",
      task_id="reinforcement-learning",
      metrics_pretty_name="mean_reward",
      metrics_id="mean_reward",
      metrics_value=f"{mean_reward:.2f} +/- {std_reward:.2f}",
      dataset_pretty_name=env_id,
      dataset_id=env_id,
  )

  # Merges both dictionaries
  metadata = {**metadata, **eval}

  return metadata


def _save_model_card(local_path, generated_model_card, metadata):
    """Saves a model card for the repository.
    :param local_path: repository directory
    :param generated_model_card: model card generated by _generate_model_card()
    :param metadata: metadata
    """
    readme_path = local_path / "README.md"
    readme = ""
    if readme_path.exists():
        with readme_path.open("r", encoding="utf8") as f:
            readme = f.read()
    else:
        readme = generated_model_card

    with readme_path.open("w", encoding="utf-8") as f:
        f.write(readme)

    # Save our metrics to Readme metadata
    metadata_save(readme_path, metadata)


def _add_logdir(local_path: Path, logdir: Path):
  """Adds a logdir to the repository.
  :param local_path: repository directory
  :param logdir: logdir directory
  """
  if logdir.exists() and logdir.is_dir():
    # Add the logdir to the repository under new dir called logs
    repo_logdir = local_path / "logs"

    # Delete current logs if they exist
    if repo_logdir.exists():
      shutil.rmtree(repo_logdir)

    # Copy logdir into repo logdir
    shutil.copytree(logdir, repo_logdir)

# %% [markdown]
# - Finally, we call this function at the end of the PPO training

# %%
# Create the evaluation environment
eval_env = gym.make(args.env_id)

package_to_hub(repo_id = args.repo_id,
                model = agent, # The model we want to save
                hyperparameters = args,
                eval_env = gym.make(args.env_id),
                logs= f"runs/{run_name}",
                )

# %% [markdown]
# - Here's what look the ppo.py final file

# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/ppo/#ppopy

import argparse
import os
import random
import time
# from distutils.util import strtobool

import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from huggingface_hub import HfApi, upload_folder
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio

from wasabi import Printer
msg = Printer()

def strtobool(val):
    val = str(val).lower()
    if val in ('y', 'yes', 't', 'true', 'on', '1'):
        return True
    elif val in ('n', 'no', 'f', 'false', 'off', '0'):
        return False
    else:
        raise ValueError(f"Invalid truth value: {val!r}")

def parse_args():
    # fmt: off
    parser = argparse.ArgumentParser()
    parser.add_argument("--exp-name", type=str, default=os.path.basename(__file__).rstrip(".py"),
        help="the name of this experiment")
    parser.add_argument("--seed", type=int, default=1,
        help="seed of the experiment")
    parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="if toggled, `torch.backends.cudnn.deterministic=False`")
    parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="if toggled, cuda will be enabled by default")
    parser.add_argument("--track", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="if toggled, this experiment will be tracked with Weights and Biases")
    parser.add_argument("--wandb-project-name", type=str, default="cleanRL",
        help="the wandb's project name")
    parser.add_argument("--wandb-entity", type=str, default=None,
        help="the entity (team) of wandb's project")
    parser.add_argument("--capture-video", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="weather to capture videos of the agent performances (check out `videos` folder)")

    # Algorithm specific arguments
    parser.add_argument("--env-id", type=str, default="CartPole-v1",
        help="the id of the environment")
    parser.add_argument("--total-timesteps", type=int, default=50000,
        help="total timesteps of the experiments")
    parser.add_argument("--learning-rate", type=float, default=2.5e-4,
        help="the learning rate of the optimizer")
    parser.add_argument("--num-envs", type=int, default=4,
        help="the number of parallel game environments")
    parser.add_argument("--num-steps", type=int, default=128,
        help="the number of steps to run in each environment per policy rollout")
    parser.add_argument("--anneal-lr", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggle learning rate annealing for policy and value networks")
    parser.add_argument("--gae", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Use GAE for advantage computation")
    parser.add_argument("--gamma", type=float, default=0.99,
        help="the discount factor gamma")
    parser.add_argument("--gae-lambda", type=float, default=0.95,
        help="the lambda for the general advantage estimation")
    parser.add_argument("--num-minibatches", type=int, default=4,
        help="the number of mini-batches")
    parser.add_argument("--update-epochs", type=int, default=4,
        help="the K epochs to update the policy")
    parser.add_argument("--norm-adv", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggles advantages normalization")
    parser.add_argument("--clip-coef", type=float, default=0.2,
        help="the surrogate clipping coefficient")
    parser.add_argument("--clip-vloss", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggles whether or not to use a clipped loss for the value function, as per the paper.")
    parser.add_argument("--ent-coef", type=float, default=0.01,
        help="coefficient of the entropy")
    parser.add_argument("--vf-coef", type=float, default=0.5,
        help="coefficient of the value function")
    parser.add_argument("--max-grad-norm", type=float, default=0.5,
        help="the maximum norm for the gradient clipping")
    parser.add_argument("--target-kl", type=float, default=None,
        help="the target KL divergence threshold")

    # Adding HuggingFace argument
    parser.add_argument("--repo-id", type=str, default="ThomasSimonini/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")

    args = parser.parse_args()
    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    # fmt: on
    return args

def package_to_hub(repo_id,
                model,
                hyperparameters,
                eval_env,
                video_fps=30,
                commit_message="Push agent to the Hub",
                token= None,
                logs=None
                ):
  """
  Evaluate, Generate a video and Upload a model to Hugging Face Hub.
  This method does the complete pipeline:
  - It evaluates the model
  - It generates the model card
  - It generates a replay video of the agent
  - It pushes everything to the hub
  :param repo_id: id of the model repository from the Hugging Face Hub
  :param model: trained model
  :param eval_env: environment used to evaluate the agent
  :param fps: number of fps for rendering the video
  :param commit_message: commit message
  :param logs: directory on local machine of tensorboard logs you'd like to upload
  """
  msg.info(
        "This function will save, evaluate, generate a video of your agent, "
        "create a model card and push everything to the hub. "
        "It might take up to 1min. \n "
        "This is a work in progress: if you encounter a bug, please open an issue."
    )
  # Step 1: Clone or create the repo
  repo_url = HfApi().create_repo(
        repo_id=repo_id,
        token=token,
        private=False,
        exist_ok=True,
    )

  with tempfile.TemporaryDirectory() as tmpdirname:
    tmpdirname = Path(tmpdirname)

    # Step 2: Save the model
    torch.save(model.state_dict(), tmpdirname / "model.pt")

    # Step 3: Evaluate the model and build JSON
    mean_reward, std_reward = _evaluate_agent(eval_env,
                                           10,
                                           model)

    # First get datetime
    eval_datetime = datetime.datetime.now()
    eval_form_datetime = eval_datetime.isoformat()

    evaluate_data = {
        "env_id": hyperparameters.env_id,
        "mean_reward": mean_reward,
        "std_reward": std_reward,
        "n_evaluation_episodes": 10,
        "eval_datetime": eval_form_datetime,
    }

    # Write a JSON file
    with open(tmpdirname / "results.json", "w") as outfile:
      json.dump(evaluate_data, outfile)

    # Step 4: Generate a video
    video_path =  tmpdirname / "replay.mp4"
    record_video(eval_env, model, video_path, video_fps)

    # Step 5: Generate the model card
    generated_model_card, metadata = _generate_model_card("PPO", hyperparameters.env_id, mean_reward, std_reward, hyperparameters)
    _save_model_card(tmpdirname, generated_model_card, metadata)

    # Step 6: Add logs if needed
    if logs:
      _add_logdir(tmpdirname, Path(logs))

    msg.info(f"Pushing repo {repo_id} to the Hugging Face Hub")

    repo_url = upload_folder(
            repo_id=repo_id,
            folder_path=tmpdirname,
            path_in_repo="",
            commit_message=commit_message,
            token=token,
        )

    msg.info(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
  return repo_url

def _evaluate_agent(env, n_eval_episodes, policy):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param policy: The agent
  """
  episode_rewards = []
  for episode in range(n_eval_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards_ep = 0

    while done is False:
      state = torch.Tensor(state).to(device)
      action, _, _, _ = policy.get_action_and_value(state)
      new_state, reward, done, info = env.step(action.cpu().numpy())
      total_rewards_ep += reward
      if done:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward


def record_video(env, policy, out_directory, fps=30):
  images = []
  done = False
  state = env.reset()
  img = env.render(mode='rgb_array')
  images.append(img)
  while not done:
    state = torch.Tensor(state).to(device)
    # Take the action (index) that have the maximum expected future reward given that state
    action, _, _, _  = policy.get_action_and_value(state)
    state, reward, done, info = env.step(action.cpu().numpy()) # We directly put next_state = state for recording logic
    img = env.render(mode='rgb_array')
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)


def _generate_model_card(model_name, env_id, mean_reward, std_reward, hyperparameters):
  """
  Generate the model card for the Hub
  :param model_name: name of the model
  :env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  :hyperparameters: training arguments
  """
  # Step 1: Select the tags
  metadata = generate_metadata(model_name, env_id, mean_reward, std_reward)

  # Transform the hyperparams namespace to string
  converted_dict = vars(hyperparameters)
  converted_str = str(converted_dict)
  converted_str = converted_str.split(", ")
  converted_str = '\n'.join(converted_str)

  # Step 2: Generate the model card
  model_card = f"""
  # PPO Agent Playing {env_id}

  This is a trained model of a PPO agent playing {env_id}.

  # Hyperparameters
  ```python
  {converted_str}
  ```
  """
  return model_card, metadata

def generate_metadata(model_name, env_id, mean_reward, std_reward):
  """
  Define the tags for the model card
  :param model_name: name of the model
  :param env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  """
  metadata = {}
  metadata["tags"] = [
        env_id,
        "ppo",
        "deep-reinforcement-learning",
        "reinforcement-learning",
        "custom-implementation",
        "deep-rl-course"
  ]

  # Add metrics
  eval = metadata_eval_result(
      model_pretty_name=model_name,
      task_pretty_name="reinforcement-learning",
      task_id="reinforcement-learning",
      metrics_pretty_name="mean_reward",
      metrics_id="mean_reward",
      metrics_value=f"{mean_reward:.2f} +/- {std_reward:.2f}",
      dataset_pretty_name=env_id,
      dataset_id=env_id,
  )

  # Merges both dictionaries
  metadata = {**metadata, **eval}

  return metadata

def _save_model_card(local_path, generated_model_card, metadata):
    """Saves a model card for the repository.
    :param local_path: repository directory
    :param generated_model_card: model card generated by _generate_model_card()
    :param metadata: metadata
    """
    readme_path = local_path / "README.md"
    readme = ""
    if readme_path.exists():
        with readme_path.open("r", encoding="utf8") as f:
            readme = f.read()
    else:
        readme = generated_model_card

    with readme_path.open("w", encoding="utf-8") as f:
        f.write(readme)

    # Save our metrics to Readme metadata
    metadata_save(readme_path, metadata)

def _add_logdir(local_path: Path, logdir: Path):
  """Adds a logdir to the repository.
  :param local_path: repository directory
  :param logdir: logdir directory
  """
  if logdir.exists() and logdir.is_dir():
    # Add the logdir to the repository under new dir called logs
    repo_logdir = local_path / "logs"

    # Delete current logs if they exist
    if repo_logdir.exists():
      shutil.rmtree(repo_logdir)

    # Copy logdir into repo logdir
    shutil.copytree(logdir, repo_logdir)

def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        if capture_video:
            if idx == 0:
                env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        env.seed(seed)
        env.action_space.seed(seed)
        env.observation_space.seed(seed)
        return env

    return thunk


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), std=1.0),
        )
        self.actor = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, envs.single_action_space.n), std=0.01),
        )

    def get_value(self, x):
        return self.critic(x)

    def get_action_and_value(self, x, action=None):
        logits = self.actor(x)
        probs = Categorical(logits=logits)
        if action is None:
            action = probs.sample()
        return action, probs.log_prob(action), probs.entropy(), self.critic(x)


if __name__ == "__main__":
    args = parse_args()
    run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
    if args.track:
        import wandb

        wandb.init(
            project=args.wandb_project_name,
            entity=args.wandb_entity,
            sync_tensorboard=True,
            config=vars(args),
            name=run_name,
            monitor_gym=True,
            save_code=True,
        )
    writer = SummaryWriter(f"runs/{run_name}")
    writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
    )

    # TRY NOT TO MODIFY: seeding
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = args.torch_deterministic

    device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

    # env setup
    envs = gym.vector.SyncVectorEnv(
        [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
    )
    assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

    agent = Agent(envs).to(device)
    optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

    # ALGO Logic: Storage setup
    obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
    actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
    logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
    rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
    dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
    values = torch.zeros((args.num_steps, args.num_envs)).to(device)

    # TRY NOT TO MODIFY: start the game
    global_step = 0
    start_time = time.time()
    next_obs = torch.Tensor(envs.reset()).to(device)
    next_done = torch.zeros(args.num_envs).to(device)
    num_updates = args.total_timesteps // args.batch_size

    for update in range(1, num_updates + 1):
        # Annealing the rate if instructed to do so.
        if args.anneal_lr:
            frac = 1.0 - (update - 1.0) / num_updates
            lrnow = frac * args.learning_rate
            optimizer.param_groups[0]["lr"] = lrnow

        for step in range(0, args.num_steps):
            global_step += 1 * args.num_envs
            obs[step] = next_obs
            dones[step] = next_done

            # ALGO LOGIC: action logic
            with torch.no_grad():
                action, logprob, _, value = agent.get_action_and_value(next_obs)
                values[step] = value.flatten()
            actions[step] = action
            logprobs[step] = logprob

            # TRY NOT TO MODIFY: execute the game and log data.
            next_obs, reward, done, info = envs.step(action.cpu().numpy())
            rewards[step] = torch.tensor(reward).to(device).view(-1)
            next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

            for item in info:
                if "episode" in item.keys():
                    print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
                    writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step)
                    writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step)
                    break

        # bootstrap value if not done
        with torch.no_grad():
            next_value = agent.get_value(next_obs).reshape(1, -1)
            if args.gae:
                advantages = torch.zeros_like(rewards).to(device)
                lastgaelam = 0
                for t in reversed(range(args.num_steps)):
                    if t == args.num_steps - 1:
                        nextnonterminal = 1.0 - next_done
                        nextvalues = next_value
                    else:
                        nextnonterminal = 1.0 - dones[t + 1]
                        nextvalues = values[t + 1]
                    delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
                    advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
                returns = advantages + values
            else:
                returns = torch.zeros_like(rewards).to(device)
                for t in reversed(range(args.num_steps)):
                    if t == args.num_steps - 1:
                        nextnonterminal = 1.0 - next_done
                        next_return = next_value
                    else:
                        nextnonterminal = 1.0 - dones[t + 1]
                        next_return = returns[t + 1]
                    returns[t] = rewards[t] + args.gamma * nextnonterminal * next_return
                advantages = returns - values

        # flatten the batch
        b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
        b_logprobs = logprobs.reshape(-1)
        b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)
        b_values = values.reshape(-1)

        # Optimizing the policy and value network
        b_inds = np.arange(args.batch_size)
        clipfracs = []
        for epoch in range(args.update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, args.batch_size, args.minibatch_size):
                end = start + args.minibatch_size
                mb_inds = b_inds[start:end]

                _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()

                with torch.no_grad():
                    # calculate approx_kl http://joschu.net/blog/kl-approx.html
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio - 1) - logratio).mean()
                    clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean().item()]

                mb_advantages = b_advantages[mb_inds]
                if args.norm_adv:
                    mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                # Policy loss
                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()

                # Value loss
                newvalue = newvalue.view(-1)
                if args.clip_vloss:
                    v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                    v_clipped = b_values[mb_inds] + torch.clamp(
                        newvalue - b_values[mb_inds],
                        -args.clip_coef,
                        args.clip_coef,
                    )
                    v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                    v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                    v_loss = 0.5 * v_loss_max.mean()
                else:
                    v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

                entropy_loss = entropy.mean()
                loss = pg_loss - args.ent_coef * entropy_loss + v_loss * args.vf_coef

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
                optimizer.step()

            if args.target_kl is not None:
                if approx_kl > args.target_kl:
                    break

        y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
        var_y = np.var(y_true)
        explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

        # TRY NOT TO MODIFY: record rewards for plotting purposes
        writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
        writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
        writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
        writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
        writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
        writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
        writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step)
        writer.add_scalar("losses/explained_variance", explained_var, global_step)
        print("SPS:", int(global_step / (time.time() - start_time)))
        writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

    envs.close()
    writer.close()

    # Create the evaluation environment
    eval_env = gym.make(args.env_id)

    package_to_hub(repo_id = args.repo_id,
                model = agent, # The model we want to save
                hyperparameters = args,
                eval_env = gym.make(args.env_id),
                logs= f"runs/{run_name}",
                )

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import notebook_login
# notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# ## Let's start the training 🔥
# - ⚠️ ⚠️ ⚠️  Don't use **the same repo id with the one you used for the Unit 1**
# - Now that you've coded from scratch PPO and added the Hugging Face Integration, we're ready to start the training 🔥

# %%
import os
from huggingface_hub import HfApi, login

def authenticate_huggingface():
    """Robust authentication for Colab, Kaggle, and Local environments."""
    hf_token = None

    # 1. Try Google Colab Secrets
    try:
        from google.colab import userdata
        try:
            hf_token = userdata.get("HF_TOKEN")
        except userdata.SecretNotFoundError:
            print("💡 Instruction: Add 'HF_TOKEN' to the Secrets tab (key icon) and enable access.")
    except (ImportError, ModuleNotFoundError):
        pass

    # 2. Try Kaggle Secrets (if not on Colab)
    if not hf_token:
        try:
            from kaggle_secrets import UserSecretsClient
            hf_token = UserSecretsClient().get_secret("HF_TOKEN")
        except (ImportError, ModuleNotFoundError, Exception):
            pass

    # 3. Try Environment Variables (Local/Docker)
    if not hf_token:
        hf_token = os.getenv("HF_TOKEN")

    if not hf_token:
        print("⚠️ No token found. Please set HF_TOKEN in your environment/secrets.")
        return False

    # Perform Login
    try:
        login(token=hf_token, add_to_git_credential=True)
        api = HfApi()
        user_info = api.whoami()
        print(f"✅ Logged in as: {user_info['name']}")
        return True
    except Exception as e:
        print(f"❌ Login failed: {e}")
        return False

# Execute
authenticate_huggingface()
# Out:
# ✅ Logged in as: Chiz
# True

# %% [markdown]
# - First, you need to copy all your code to a file you create called `ppo.py`

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/step1.png" alt="PPO"/>

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/step2.png" alt="PPO"/>

# %% [markdown]
# - Now we just need to run this python script using `python <name-of-python-script>.py` with the additional parameters we defined with `argparse`
#
# - You should modify more hyperparameters otherwise the training will not be super stable.

# %%
# !python ppo.py --env-id="LunarLander-v2" --repo-id="Chiz" --total-timesteps=50000

# %%
# !pip install gym[box2d] gymnasium
# !pip install box2d-py
# !pip install gymnasium[box2d] stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d==2.3.10 (from gymnasium[box2d])
#   Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (573 bytes)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu128)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.21.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 67.1 MB/s eta 0:00:00
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 108.8 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 17.7 MB/s eta 0:00:00
# Installing collected packages: swig, box2d, stable-baselines3
# Successfully installed box2d-2.3.10 stable-baselines3-2.7.1 swig-4.4.1

# %%
# !python ppo.py \
  --env-id="LunarLander-v2" \
  --repo-id="Chiz/ppo-LunarLander-v2" \
  --total-timesteps=1000000 \
  --learning-rate=3e-4 \
  --num-envs=16 \
  --num-steps=512 \
  --gamma=0.999 \
  --gae-lambda=0.98 \
  --num-minibatches=4 \
  --update-epochs=4 \
  --clip-coef=0.2 \
  --ent-coef=0.01 \
  --vf-coef=0.5 \
  --max-grad-norm=0.5 \
  --target-kl=0.015 \
  --anneal-lr=True \
  --gae=True \
  --norm-adv=True \
  --clip-vloss=True
# Out:
# Streaming output truncated to the last 5000 lines.
# global_step=259904, episodic_return=-112.81641387939453
# global_step=259952, episodic_return=-94.92054748535156
# global_step=260000, episodic_return=-83.27069091796875
# global_step=260016, episodic_return=-20.380844116210938
# global_step=260272, episodic_return=-123.12652587890625
# global_step=260752, episodic_return=-154.81759643554688
# global_step=260800, episodic_return=-133.22467041015625
# global_step=260928, episodic_return=-58.5655632019043
# global_step=261072, episodic_return=-71.9697265625
# global_step=261152, episodic_return=-91.2805404663086
# global_step=261168, episodic_return=-126.68614196777344
# global_step=261360, episodic_return=-126.56214904785156
# global_step=261408, episodic_return=-91.50617980957031
# global_step=261536, episodic_return=-80.25674438476562
# global_step=261568, episodic_return=-80.61287689208984
# global_step=261664, episodic_return=-95.54706573486328
# global_step=261872, episodic_return=-74.10773468017578
# global_step=261952, episodic_return=-120.7147216796875
# global_step=262080, episodic_return=-194.77528381347656
# SPS: 3178
# global_step=262192, episodic_return=-64.33091735839844
# global_step=262448, episodic_return=-67.51618957519531
# global_step=262736, episodic_return=-186.29013061523438
# global_step=262848, episodic_return=-345.39910888671875
# global_step=263008, episodic_return=-191.19650268554688
# global_step=263024, episodic_return=-125.20552825927734
# global_step=263424, episodic_return=-85.65487670898438
# global_step=263520, episodic_return=-66.03733825683594
# global_step=263584, episodic_return=-82.58016204833984
# global_step=263808, episodic_return=-38.212528228759766
# global_step=263840, episodic_return=-128.619873046875
# global_step=263904, episodic_return=-111.1115951538086
# global_step=264128, episodic_return=-69.31266784667969
# global_step=264144, episodic_return=-134.38177490234375
# global_step=264304, episodic_return=-127.72470092773438
# global_step=264352, episodic_return=-104.7928695678711
# global_step=264400, episodic_return=-196.06529235839844
# global_step=264640, episodic_return=-51.38829803466797
# global_step=264864, episodic_return=-29.263938903808594
# global_step=264992, episodic_return=-97.47077178955078
# global_step=265056, episodic_return=-96.7027587890625
# global_step=265120, episodic_return=-253.48191833496094
# global_step=265232, episodic_return=-203.06468200683594
# global_step=265456, episodic_return=-138.0240936279297
# global_step=265472, episodic_return=-78.51175689697266
# global_step=265488, episodic_return=-108.14228820800781
# global_step=265520, episodic_return=-76.38788604736328
# global_step=265568, episodic_return=-87.29161834716797
# global_step=265856, episodic_return=-192.13766479492188
# global_step=265968, episodic_return=-57.03992462158203
# global_step=266016, episodic_return=-98.47166442871094
# global_step=266176, episodic_return=-144.05958557128906
# global_step=266208, episodic_return=-143.06832885742188
# global_step=266544, episodic_return=-140.5283203125
# global_step=266592, episodic_return=-65.74958038330078
# global_step=266688, episodic_return=-9.387382507324219
# global_step=266720, episodic_return=-108.32748413085938
# global_step=266736, episodic_return=-71.91694641113281
# global_step=266928, episodic_return=-119.92581176757812
# global_step=267040, episodic_return=-93.14012908935547
# global_step=267072, episodic_return=-71.24609375
# global_step=267120, episodic_return=-76.26875305175781
# global_step=267200, episodic_return=-227.8729248046875
# global_step=267760, episodic_return=-93.15033721923828
# global_step=267920, episodic_return=-42.176170349121094
# global_step=267936, episodic_return=-71.1878662109375
# global_step=267968, episodic_return=-77.97743225097656
# global_step=268016, episodic_return=-91.32505798339844
# global_step=268128, episodic_return=-63.89925765991211
# global_step=268144, episodic_return=-104.58043670654297
# global_step=268240, episodic_return=-99.2473373413086
# global_step=268384, episodic_return=-233.73521423339844
# global_step=268448, episodic_return=-141.88565063476562
# global_step=268592, episodic_return=-81.0636215209961
# global_step=268752, episodic_return=-101.2536392211914
# global_step=268768, episodic_return=-243.54727172851562
# global_step=269280, episodic_return=-220.81753540039062
# global_step=269328, episodic_return=-230.2622528076172
# global_step=269360, episodic_return=-59.397212982177734
# global_step=269424, episodic_return=-55.06547927856445
# global_step=269456, episodic_return=-110.84739685058594
# global_step=269520, episodic_return=-115.2353744506836
# global_step=269824, episodic_return=-118.99803924560547
# global_step=270016, episodic_return=-100.94243621826172
# global_step=270064, episodic_return=-106.94098663330078
# global_step=270160, episodic_return=-64.94110107421875
# global_step=270192, episodic_return=-59.51148986816406
# SPS: 3182
# global_step=270432, episodic_return=-45.07628631591797
# global_step=270576, episodic_return=-72.75938415527344
# global_step=270608, episodic_return=-93.87281799316406
# global_step=270672, episodic_return=-29.27605438232422
# global_step=270832, episodic_return=-57.26264190673828
# global_step=270912, episodic_return=-197.1715087890625
# global_step=270928, episodic_return=-128.99855041503906
# global_step=271120, episodic_return=-76.75958251953125
# global_step=271424, episodic_return=-218.11679077148438
# global_step=271472, episodic_return=-101.328125
# global_step=271552, episodic_return=-296.7752380371094
# global_step=271760, episodic_return=-92.95712280273438
# global_step=271824, episodic_return=-29.47552490234375
# global_step=271856, episodic_return=-74.82524871826172
# global_step=271888, episodic_return=-138.71084594726562
# global_step=271904, episodic_return=-76.32878875732422
# global_step=272032, episodic_return=-81.65809631347656
# global_step=272144, episodic_return=-92.111083984375
# global_step=272256, episodic_return=-91.57227325439453
# global_step=272320, episodic_return=-130.70843505859375
# global_step=272496, episodic_return=-16.416854858398438
# global_step=272768, episodic_return=-32.171669006347656
# global_step=272880, episodic_return=-91.49877166748047
# global_step=273088, episodic_return=-92.62820434570312
# global_step=273136, episodic_return=-68.99114990234375
# global_step=273264, episodic_return=-106.35491943359375
# global_step=273376, episodic_return=-179.562744140625
# global_step=273408, episodic_return=-55.69208908081055
# global_step=273456, episodic_return=-142.4528350830078
# global_step=273536, episodic_return=-55.82298278808594
# global_step=273584, episodic_return=-173.71084594726562
# global_step=274000, episodic_return=-175.17794799804688
# global_step=274016, episodic_return=-126.01698303222656
# global_step=274224, episodic_return=-267.578125
# global_step=274416, episodic_return=-73.80705261230469
# global_step=274624, episodic_return=-68.56599426269531
# global_step=274784, episodic_return=-60.96100997924805
# global_step=274800, episodic_return=-83.90582275390625
# global_step=274848, episodic_return=-62.15869903564453
# global_step=274864, episodic_return=-65.17766571044922
# global_step=274976, episodic_return=-75.29568481445312
# global_step=274992, episodic_return=-7.21392822265625
# global_step=275008, episodic_return=-51.14134979248047
# global_step=275216, episodic_return=-35.329994201660156
# global_step=275552, episodic_return=-57.948333740234375
# global_step=275664, episodic_return=-164.2803955078125
# global_step=275712, episodic_return=-59.17425537109375
# global_step=275808, episodic_return=-179.6272430419922
# global_step=275984, episodic_return=-57.754425048828125
# global_step=276176, episodic_return=-49.46769332885742
# global_step=276208, episodic_return=-98.57881164550781
# global_step=276256, episodic_return=-21.850387573242188
# global_step=276336, episodic_return=-128.0643768310547
# global_step=276464, episodic_return=-155.94029235839844
# global_step=276608, episodic_return=-300.24737548828125
# global_step=276800, episodic_return=-87.34364318847656
# global_step=276880, episodic_return=9.862312316894531
# global_step=276992, episodic_return=-75.89701843261719
# global_step=277056, episodic_return=-88.10896301269531
# global_step=277520, episodic_return=-74.77790832519531
# global_step=277584, episodic_return=-63.037288665771484
# global_step=277712, episodic_return=-93.75347137451172
# global_step=277824, episodic_return=-91.80729675292969
# global_step=277904, episodic_return=-92.98503112792969
# global_step=278032, episodic_return=-95.4210205078125
# global_step=278160, episodic_return=-74.54959869384766
# global_step=278272, episodic_return=-185.71189880371094
# global_step=278528, episodic_return=-29.03954315185547
# SPS: 3160
# global_step=278768, episodic_return=9.857688903808594
# global_step=278832, episodic_return=-103.05909729003906
# global_step=279072, episodic_return=-165.7335205078125
# global_step=279104, episodic_return=-386.6515808105469
# global_step=279136, episodic_return=-92.2491455078125
# global_step=279184, episodic_return=-246.683349609375
# global_step=279232, episodic_return=-204.03598022460938
# global_step=279344, episodic_return=-155.71456909179688
# global_step=279776, episodic_return=-246.4812774658203
# global_step=279808, episodic_return=-143.9312744140625
# global_step=279872, episodic_return=-79.35636901855469
# global_step=280192, episodic_return=-68.00761413574219
# global_step=280400, episodic_return=-46.66291427612305
# global_step=280448, episodic_return=-147.00433349609375
# global_step=280592, episodic_return=-179.39450073242188
# global_step=280608, episodic_return=-206.40475463867188
# global_step=280672, episodic_return=-73.2904052734375
# global_step=280736, episodic_return=-174.15158081054688
# global_step=281008, episodic_return=-301.1637878417969
# global_step=281040, episodic_return=-71.7676010131836
# global_step=281152, episodic_return=-298.63714599609375
# global_step=281248, episodic_return=-204.74188232421875
# global_step=281488, episodic_return=-51.42150115966797
# global_step=281584, episodic_return=-85.12890625
# global_step=281872, episodic_return=-74.1379165649414
# global_step=282048, episodic_return=-31.137596130371094
# global_step=282096, episodic_return=-91.49649810791016
# global_step=282176, episodic_return=-59.27998733520508
# global_step=282208, episodic_return=-47.50942611694336
# global_step=282256, episodic_return=-78.33927917480469
# global_step=282352, episodic_return=-139.19439697265625
# global_step=282384, episodic_return=-39.85166931152344
# global_step=282688, episodic_return=-140.05364990234375
# global_step=282816, episodic_return=-58.72439956665039
# global_step=283008, episodic_return=-96.6895751953125
# global_step=283232, episodic_return=-134.60671997070312
# global_step=283264, episodic_return=-70.90779113769531
# global_step=283408, episodic_return=-99.4532470703125
# global_step=283520, episodic_return=-287.4875793457031
# global_step=283536, episodic_return=-122.69497680664062
# global_step=283712, episodic_return=-117.95646667480469
# global_step=283824, episodic_return=-97.26478576660156
# global_step=284016, episodic_return=-122.19975280761719
# global_step=284080, episodic_return=-51.092472076416016
# global_step=284112, episodic_return=-261.5763854980469
# global_step=284672, episodic_return=-57.7357063293457
# global_step=284800, episodic_return=-63.654624938964844
# global_step=284880, episodic_return=-112.30565643310547
# global_step=284912, episodic_return=-167.81680297851562
# global_step=285008, episodic_return=-161.1901092529297
# global_step=285040, episodic_return=-189.97415161132812
# global_step=285216, episodic_return=-36.97547149658203
# global_step=285440, episodic_return=-102.6293716430664
# global_step=285632, episodic_return=-39.11253356933594
# global_step=285664, episodic_return=-121.60829162597656
# global_step=285744, episodic_return=-56.06687927246094
# global_step=285936, episodic_return=-88.83918762207031
# global_step=285984, episodic_return=-28.73004150390625
# global_step=286336, episodic_return=-266.478515625
# global_step=286352, episodic_return=-49.99880599975586
# global_step=286512, episodic_return=-61.77016830444336
# global_step=286544, episodic_return=-64.8092269897461
# global_step=286560, episodic_return=-109.29399108886719
# global_step=286608, episodic_return=-120.39369201660156
# SPS: 3160
# global_step=286976, episodic_return=-35.88605499267578
# global_step=287072, episodic_return=-109.5743179321289
# global_step=287136, episodic_return=-104.10275268554688
# global_step=287424, episodic_return=-125.7944564819336
# global_step=287520, episodic_return=-195.81956481933594
# global_step=287568, episodic_return=-90.33122253417969
# global_step=287600, episodic_return=-88.29080200195312
# global_step=287760, episodic_return=-75.24223327636719
# global_step=287872, episodic_return=-62.88062286376953
# global_step=287984, episodic_return=-170.11915588378906
# global_step=288144, episodic_return=-101.49263763427734
# global_step=288256, episodic_return=-95.81236267089844
# global_step=288336, episodic_return=-76.21842956542969
# global_step=288448, episodic_return=-116.62857055664062
# global_step=288560, episodic_return=-163.70706176757812
# global_step=288784, episodic_return=-97.74842834472656
# global_step=288848, episodic_return=-87.1891860961914
# global_step=288896, episodic_return=-114.8851089477539
# global_step=288928, episodic_return=-55.092201232910156
# global_step=288944, episodic_return=-72.86331176757812
# global_step=288960, episodic_return=-81.6255874633789
# global_step=289408, episodic_return=-115.36097717285156
# global_step=289536, episodic_return=-63.78474426269531
# global_step=289760, episodic_return=-42.07352828979492
# global_step=289856, episodic_return=-83.99946594238281
# global_step=290032, episodic_return=-85.96441650390625
# global_step=290064, episodic_return=-52.20008850097656
# global_step=290096, episodic_return=-143.11373901367188
# global_step=290224, episodic_return=-110.97904205322266
# global_step=290240, episodic_return=-47.698307037353516
# global_step=290304, episodic_return=-82.811279296875
# global_step=290416, episodic_return=-154.1593475341797
# global_step=291152, episodic_return=-40.570682525634766
# global_step=291232, episodic_return=-220.01864624023438
# global_step=291264, episodic_return=-79.59418487548828
# global_step=291280, episodic_return=-135.2626953125
# global_step=291376, episodic_return=-85.4935302734375
# global_step=291392, episodic_return=-112.82369995117188
# global_step=291536, episodic_return=-198.2964324951172
# global_step=291552, episodic_return=-15.299827575683594
# global_step=291584, episodic_return=-99.14451599121094
# global_step=291600, episodic_return=-96.58068084716797
# global_step=291760, episodic_return=-108.52908325195312
# global_step=291904, episodic_return=-154.53411865234375
# global_step=292176, episodic_return=-229.29481506347656
# global_step=292752, episodic_return=-93.61748504638672
# global_step=292832, episodic_return=-102.49370574951172
# global_step=292896, episodic_return=-76.54485321044922
# global_step=293008, episodic_return=-84.64476013183594
# global_step=293120, episodic_return=-82.8800048828125
# global_step=293168, episodic_return=-158.0286865234375
# global_step=293216, episodic_return=17.198562622070312
# global_step=293296, episodic_return=-92.99966430664062
# global_step=293552, episodic_return=-91.7767562866211
# global_step=293584, episodic_return=-116.58937072753906
# global_step=293728, episodic_return=-71.38404083251953
# global_step=293824, episodic_return=-69.27784729003906
# global_step=294192, episodic_return=-268.3609619140625
# global_step=294240, episodic_return=-65.0631103515625
# global_step=294432, episodic_return=-98.6550064086914
# global_step=294528, episodic_return=-64.20285034179688
# global_step=294832, episodic_return=-114.95059204101562
# global_step=294864, episodic_return=-74.17716217041016
# SPS: 3142
# global_step=295024, episodic_return=-93.63220977783203
# global_step=295136, episodic_return=-120.59574127197266
# global_step=295216, episodic_return=-109.49253845214844
# global_step=295360, episodic_return=-112.99559020996094
# global_step=295520, episodic_return=-84.21861267089844
# global_step=295536, episodic_return=-111.80795288085938
# global_step=295616, episodic_return=-228.17868041992188
# global_step=295824, episodic_return=-156.67706298828125
# global_step=295968, episodic_return=-107.59233856201172
# global_step=296000, episodic_return=-85.32115173339844
# global_step=296096, episodic_return=-46.91654586791992
# global_step=296288, episodic_return=-132.89401245117188
# global_step=296688, episodic_return=-99.53713989257812
# global_step=296720, episodic_return=-26.670082092285156
# global_step=296768, episodic_return=-109.5252914428711
# global_step=296864, episodic_return=-97.13446807861328
# global_step=296960, episodic_return=-39.72396469116211
# global_step=296992, episodic_return=-129.89056396484375
# global_step=297136, episodic_return=-42.44947814941406
# global_step=297312, episodic_return=-60.41519546508789
# global_step=297392, episodic_return=6.02435302734375
# global_step=297808, episodic_return=-224.34153747558594
# global_step=297920, episodic_return=-87.73262023925781
# global_step=297968, episodic_return=-125.46018981933594
# global_step=298064, episodic_return=-76.02168273925781
# global_step=298256, episodic_return=65.82597351074219
# global_step=298272, episodic_return=-206.25222778320312
# global_step=298320, episodic_return=-122.98889923095703
# global_step=298464, episodic_return=-80.29304504394531
# global_step=298576, episodic_return=-70.22628784179688
# global_step=298912, episodic_return=-83.26708984375
# global_step=298976, episodic_return=-104.75318908691406
# global_step=298992, episodic_return=-123.84846496582031
# global_step=299056, episodic_return=-52.0062141418457
# global_step=299168, episodic_return=-57.649410247802734
# global_step=299616, episodic_return=-158.73692321777344
# global_step=299632, episodic_return=-51.89597702026367
# global_step=299920, episodic_return=-96.12886810302734
# global_step=300000, episodic_return=-26.340530395507812
# global_step=300064, episodic_return=-120.0545425415039
# global_step=300224, episodic_return=-31.17548370361328
# global_step=300400, episodic_return=-137.2122802734375
# global_step=300416, episodic_return=-116.8544921875
# global_step=300496, episodic_return=-64.282470703125
# global_step=300512, episodic_return=-26.864891052246094
# global_step=300688, episodic_return=-70.13740539550781
# global_step=300768, episodic_return=-82.25148010253906
# global_step=300816, episodic_return=-169.28428649902344
# global_step=301136, episodic_return=-4.588134765625
# global_step=301216, episodic_return=-109.77835083007812
# global_step=301296, episodic_return=-85.8402099609375
# global_step=301328, episodic_return=-69.2862777709961
# global_step=301424, episodic_return=-97.99300384521484
# global_step=301696, episodic_return=-87.16304016113281
# global_step=301856, episodic_return=-80.21559143066406
# global_step=302080, episodic_return=-71.07999420166016
# global_step=302096, episodic_return=-88.65737915039062
# global_step=302192, episodic_return=-84.14813232421875
# global_step=302304, episodic_return=-69.54924774169922
# global_step=302448, episodic_return=-6.704978942871094
# global_step=302480, episodic_return=-235.58209228515625
# global_step=302560, episodic_return=-129.8043975830078
# global_step=302576, episodic_return=-102.11164093017578
# global_step=302624, episodic_return=-15.648193359375
# global_step=302736, episodic_return=-13.375381469726562
# global_step=302880, episodic_return=-102.025390625
# global_step=302896, episodic_return=-57.98930358886719
# global_step=303056, episodic_return=-95.09600067138672
# global_step=303088, episodic_return=-73.66210174560547
# SPS: 3099
# global_step=303232, episodic_return=-67.71800231933594
# global_step=303680, episodic_return=-86.6010971069336
# global_step=303696, episodic_return=-167.28726196289062
# global_step=303856, episodic_return=-62.83192443847656
# global_step=303888, episodic_return=-63.197879791259766
# global_step=303984, episodic_return=-97.82454681396484
# global_step=304176, episodic_return=-103.82987976074219
# global_step=304256, episodic_return=-105.25541687011719
# global_step=304272, episodic_return=-112.63887786865234
# global_step=304320, episodic_return=-63.17575454711914
# global_step=304736, episodic_return=-70.42578887939453
# global_step=304752, episodic_return=-116.93045043945312
# global_step=304784, episodic_return=-88.93963623046875
# global_step=304880, episodic_return=-149.81654357910156
# global_step=304992, episodic_return=-18.62743377685547
# global_step=305008, episodic_return=-103.79869079589844
# global_step=305056, episodic_return=-71.1913833618164
# global_step=305152, episodic_return=-94.1197509765625
# global_step=305392, episodic_return=-122.8817138671875
# global_step=305440, episodic_return=-133.5137481689453
# global_step=305632, episodic_return=-75.79710388183594
# global_step=305648, episodic_return=-65.06172180175781
# global_step=305680, episodic_return=-74.9294204711914
# global_step=305808, episodic_return=-65.93824768066406
# global_step=305968, episodic_return=-109.57771301269531
# global_step=306160, episodic_return=-84.80052185058594
# global_step=306240, episodic_return=-46.96435546875
# global_step=306368, episodic_return=-46.31708908081055
# global_step=306384, episodic_return=-52.917259216308594
# global_step=306448, episodic_return=-160.8090362548828
# global_step=306608, episodic_return=-225.97482299804688
# global_step=306624, episodic_return=-91.400146484375
# global_step=306720, episodic_return=-53.37832260131836
# global_step=306864, episodic_return=-200.85513305664062
# global_step=306976, episodic_return=-89.8285903930664
# global_step=307296, episodic_return=-87.82380676269531
# global_step=307440, episodic_return=-73.89712524414062
# global_step=307680, episodic_return=-138.95030212402344
# global_step=307776, episodic_return=-215.563232421875
# global_step=307968, episodic_return=-17.559120178222656
# global_step=308064, episodic_return=-68.38761901855469
# global_step=308096, episodic_return=-153.7266082763672
# global_step=308272, episodic_return=-42.91237258911133
# global_step=308400, episodic_return=-222.85897827148438
# global_step=308512, episodic_return=-104.92549896240234
# global_step=308576, episodic_return=-108.56013488769531
# global_step=308592, episodic_return=-106.23347473144531
# global_step=308688, episodic_return=-140.92816162109375
# global_step=308816, episodic_return=-242.85455322265625
# global_step=308976, episodic_return=-72.55712890625
# global_step=309056, episodic_return=-118.369140625
# global_step=309088, episodic_return=-199.50924682617188
# global_step=309136, episodic_return=-278.01165771484375
# global_step=309264, episodic_return=-106.77017974853516
# global_step=309616, episodic_return=-137.29273986816406
# global_step=309856, episodic_return=-111.45640563964844
# global_step=309984, episodic_return=-171.60983276367188
# global_step=310064, episodic_return=-52.640193939208984
# global_step=310096, episodic_return=-321.3512268066406
# global_step=310320, episodic_return=-44.30934143066406
# global_step=310400, episodic_return=-74.74627685546875
# global_step=310448, episodic_return=-181.5953369140625
# global_step=310480, episodic_return=-18.78839874267578
# global_step=310528, episodic_return=-48.84871292114258
# global_step=310608, episodic_return=-175.12164306640625
# global_step=310720, episodic_return=-156.94125366210938
# global_step=310816, episodic_return=-252.48715209960938
# global_step=310880, episodic_return=-279.04931640625
# SPS: 3082
# global_step=311360, episodic_return=-100.78423309326172
# global_step=311456, episodic_return=-46.33492660522461
# global_step=311520, episodic_return=-39.58790588378906
# global_step=311888, episodic_return=-80.992431640625
# global_step=311920, episodic_return=-90.80040740966797
# global_step=312208, episodic_return=-101.35443115234375
# global_step=312368, episodic_return=-233.86607360839844
# global_step=312496, episodic_return=-165.8487548828125
# global_step=312560, episodic_return=-315.2540283203125
# global_step=312608, episodic_return=-98.12642669677734
# global_step=312672, episodic_return=-122.43794250488281
# global_step=312736, episodic_return=-69.05577087402344
# global_step=312816, episodic_return=-146.2500457763672
# global_step=312864, episodic_return=15.59649658203125
# global_step=312928, episodic_return=-84.73855590820312
# global_step=312960, episodic_return=-65.27336120605469
# global_step=313328, episodic_return=-106.3836669921875
# global_step=313408, episodic_return=-101.08090209960938
# global_step=313712, episodic_return=-85.33834838867188
# global_step=313968, episodic_return=-90.8852767944336
# global_step=313984, episodic_return=-95.55371856689453
# global_step=314000, episodic_return=-30.26610565185547
# global_step=314016, episodic_return=-41.93035888671875
# global_step=314224, episodic_return=-98.1524658203125
# global_step=314256, episodic_return=-51.09770202636719
# global_step=314288, episodic_return=-81.92253875732422
# global_step=314592, episodic_return=-141.12530517578125
# global_step=314752, episodic_return=-108.7605209350586
# global_step=314944, episodic_return=-66.86128234863281
# global_step=315008, episodic_return=-137.28878784179688
# global_step=315168, episodic_return=-99.44489288330078
# global_step=315280, episodic_return=-55.52670669555664
# global_step=315520, episodic_return=-87.9889907836914
# global_step=315824, episodic_return=-44.374996185302734
# global_step=315936, episodic_return=-79.7237777709961
# global_step=315984, episodic_return=-139.19683837890625
# global_step=316032, episodic_return=-119.74034118652344
# global_step=316128, episodic_return=-80.16214752197266
# global_step=316160, episodic_return=-27.54473114013672
# global_step=316208, episodic_return=-80.08753967285156
# global_step=316288, episodic_return=-161.18313598632812
# global_step=316320, episodic_return=-235.0762176513672
# global_step=316384, episodic_return=-6.938232421875
# global_step=316464, episodic_return=-73.81515502929688
# global_step=316608, episodic_return=-66.76873779296875
# global_step=316976, episodic_return=-63.29365158081055
# global_step=317072, episodic_return=-59.75068664550781
# global_step=317104, episodic_return=-98.68704986572266
# global_step=317376, episodic_return=-70.50798034667969
# global_step=317520, episodic_return=-63.897438049316406
# global_step=317584, episodic_return=-73.39740753173828
# global_step=317632, episodic_return=-89.73848724365234
# global_step=317824, episodic_return=-100.19762420654297
# global_step=317936, episodic_return=-178.55276489257812
# global_step=317984, episodic_return=-96.53921508789062
# global_step=318096, episodic_return=-77.13651275634766
# global_step=318336, episodic_return=-129.8822479248047
# global_step=318368, episodic_return=-236.2440185546875
# global_step=318432, episodic_return=-48.44986343383789
# global_step=318480, episodic_return=-193.87393188476562
# global_step=318592, episodic_return=-111.40459442138672
# global_step=318896, episodic_return=-57.842140197753906
# global_step=318912, episodic_return=-40.96370315551758
# global_step=319120, episodic_return=-42.072261810302734
# global_step=319248, episodic_return=-226.56741333007812
# global_step=319392, episodic_return=-75.3527603149414
# SPS: 3085
# global_step=319536, episodic_return=-65.40164947509766
# global_step=319552, episodic_return=-134.188232421875
# global_step=319664, episodic_return=-88.14346313476562
# global_step=319792, episodic_return=-108.79188537597656
# global_step=320112, episodic_return=-47.556182861328125
# global_step=320256, episodic_return=-112.24369049072266
# global_step=320384, episodic_return=-51.7061767578125
# global_step=320480, episodic_return=-229.86241149902344
# global_step=320512, episodic_return=-78.47198486328125
# global_step=320576, episodic_return=-138.97659301757812
# global_step=320816, episodic_return=-104.1602554321289
# global_step=321056, episodic_return=-108.48983764648438
# global_step=321088, episodic_return=-15.236625671386719
# global_step=321200, episodic_return=-42.986637115478516
# global_step=321216, episodic_return=-38.52191162109375
# global_step=321392, episodic_return=-218.41770935058594
# global_step=321568, episodic_return=-69.23522186279297
# global_step=321664, episodic_return=-122.25965881347656
# global_step=321856, episodic_return=-293.80303955078125
# global_step=322048, episodic_return=-71.98838806152344
# global_step=322272, episodic_return=-113.436767578125
# global_step=322304, episodic_return=-94.04961395263672
# global_step=322384, episodic_return=-48.01094055175781
# global_step=322432, episodic_return=-111.10394287109375
# global_step=322528, episodic_return=-161.41836547851562
# global_step=322592, episodic_return=-80.21456146240234
# global_step=322832, episodic_return=-71.7033920288086
# global_step=322880, episodic_return=-43.48495864868164
# global_step=322976, episodic_return=-131.56224060058594
# global_step=323104, episodic_return=-222.70819091796875
# global_step=323120, episodic_return=-80.1957015991211
# global_step=323184, episodic_return=-115.5272445678711
# global_step=323344, episodic_return=-201.94638061523438
# global_step=323360, episodic_return=-58.028846740722656
# global_step=323680, episodic_return=-64.00358581542969
# global_step=323744, episodic_return=-53.48203659057617
# global_step=323824, episodic_return=-57.58259582519531
# global_step=323904, episodic_return=-75.51583862304688
# global_step=324064, episodic_return=-226.4354705810547
# global_step=324080, episodic_return=-82.18803405761719
# global_step=324192, episodic_return=-288.7779541015625
# global_step=324352, episodic_return=-178.44503784179688
# global_step=324416, episodic_return=-46.27838897705078
# global_step=324528, episodic_return=-104.92269134521484
# global_step=324656, episodic_return=-107.87931060791016
# global_step=324768, episodic_return=-72.59801483154297
# global_step=324864, episodic_return=-105.7928466796875
# global_step=324960, episodic_return=-82.3634033203125
# global_step=325088, episodic_return=-84.15603637695312
# global_step=325136, episodic_return=-70.13123321533203
# global_step=325216, episodic_return=-124.7720947265625
# global_step=325296, episodic_return=-119.6144027709961
# global_step=325344, episodic_return=-63.606353759765625
# global_step=325456, episodic_return=-221.19625854492188
# global_step=325856, episodic_return=-30.334243774414062
# global_step=325904, episodic_return=-99.65711975097656
# global_step=325936, episodic_return=-217.07205200195312
# global_step=326208, episodic_return=-31.376724243164062
# global_step=326288, episodic_return=-132.71197509765625
# global_step=326640, episodic_return=-166.7784423828125
# global_step=326672, episodic_return=-167.6241455078125
# global_step=326704, episodic_return=-104.12065124511719
# global_step=326880, episodic_return=-120.02468872070312
# global_step=326912, episodic_return=-47.95632553100586
# global_step=327088, episodic_return=-49.73540496826172
# global_step=327216, episodic_return=-89.05990600585938
# global_step=327328, episodic_return=-46.25569152832031
# global_step=327392, episodic_return=-96.09422302246094
# global_step=327440, episodic_return=-63.13591003417969
# global_step=327536, episodic_return=-12.089996337890625
# global_step=327552, episodic_return=-32.39276123046875
# global_step=327568, episodic_return=-38.905052185058594
# SPS: 3089
# global_step=328112, episodic_return=-132.27479553222656
# global_step=328144, episodic_return=-57.872291564941406
# global_step=328192, episodic_return=-67.36504364013672
# global_step=328256, episodic_return=-81.82606506347656
# global_step=328336, episodic_return=-54.048946380615234
# global_step=328416, episodic_return=-105.66556549072266
# global_step=328528, episodic_return=-148.65118408203125
# global_step=328800, episodic_return=-97.72097778320312
# global_step=329072, episodic_return=-63.73434066772461
# global_step=329120, episodic_return=-34.74059295654297
# global_step=329152, episodic_return=-82.30535125732422
# global_step=329168, episodic_return=-197.0134735107422
# global_step=329232, episodic_return=-177.7456817626953
# global_step=329696, episodic_return=-61.798404693603516
# global_step=329808, episodic_return=-75.63630676269531
# global_step=329920, episodic_return=-105.27366638183594
# global_step=329936, episodic_return=-82.67166900634766
# global_step=329952, episodic_return=-104.2028579711914
# global_step=330080, episodic_return=-96.8088607788086
# global_step=330096, episodic_return=-119.10829162597656
# global_step=330128, episodic_return=-120.00186920166016
# global_step=330144, episodic_return=-114.07223510742188
# global_step=330240, episodic_return=-67.51045227050781
# global_step=330512, episodic_return=-110.39849090576172
# global_step=330976, episodic_return=-111.27864074707031
# global_step=331040, episodic_return=-111.8895034790039
# global_step=331088, episodic_return=-58.784217834472656
# global_step=331232, episodic_return=-91.7240219116211
# global_step=331280, episodic_return=-249.07977294921875
# global_step=331424, episodic_return=-130.60699462890625
# global_step=331488, episodic_return=-50.840423583984375
# global_step=331616, episodic_return=-211.73733520507812
# global_step=331760, episodic_return=-72.25446319580078
# global_step=331856, episodic_return=-43.868804931640625
# global_step=332032, episodic_return=-265.4080505371094
# global_step=332064, episodic_return=-64.46401977539062
# global_step=332208, episodic_return=-59.762935638427734
# global_step=332288, episodic_return=-134.3262481689453
# global_step=332352, episodic_return=-189.46170043945312
# global_step=332576, episodic_return=-75.61033630371094
# global_step=332688, episodic_return=-209.22637939453125
# global_step=332704, episodic_return=-49.907588958740234
# global_step=332720, episodic_return=-60.35462188720703
# global_step=332912, episodic_return=-107.9466323852539
# global_step=332992, episodic_return=-4.052009582519531
# global_step=333104, episodic_return=-46.6633415222168
# global_step=333632, episodic_return=-86.21672058105469
# global_step=333696, episodic_return=-235.48318481445312
# global_step=333712, episodic_return=-96.3494873046875
# global_step=333728, episodic_return=-198.92474365234375
# global_step=333744, episodic_return=-289.7574157714844
# global_step=333872, episodic_return=-74.74922180175781
# global_step=333952, episodic_return=-77.86723327636719
# global_step=334128, episodic_return=-109.98236846923828
# global_step=334240, episodic_return=-156.7928009033203
# global_step=334288, episodic_return=-142.45437622070312
# global_step=334320, episodic_return=-83.54461669921875
# global_step=334784, episodic_return=-235.92153930664062
# global_step=334800, episodic_return=-10.476356506347656
# global_step=334848, episodic_return=-134.56060791015625
# global_step=335104, episodic_return=-80.9527587890625
# global_step=335120, episodic_return=-83.59420776367188
# global_step=335200, episodic_return=-42.06648635864258
# global_step=335232, episodic_return=-45.34632873535156
# global_step=335520, episodic_return=-76.00233459472656
# global_step=335552, episodic_return=-104.99844360351562
# global_step=335568, episodic_return=-72.87235260009766
# global_step=335616, episodic_return=-148.76760864257812
# global_step=335648, episodic_return=-70.77041625976562
# global_step=335696, episodic_return=-74.61862182617188
# global_step=335760, episodic_return=-78.31707000732422
# global_step=335808, episodic_return=-99.22767639160156
# SPS: 3092
# global_step=336064, episodic_return=-100.11666107177734
# global_step=336176, episodic_return=-63.730674743652344
# global_step=336432, episodic_return=-48.028324127197266
# global_step=336656, episodic_return=4.938499450683594
# global_step=336672, episodic_return=-49.95670700073242
# global_step=336768, episodic_return=-76.94949340820312
# global_step=336864, episodic_return=-48.16987228393555
# global_step=336976, episodic_return=-133.71688842773438
# global_step=337168, episodic_return=-22.8486328125
# global_step=337312, episodic_return=-271.24859619140625
# global_step=337360, episodic_return=-116.65985870361328
# global_step=337392, episodic_return=-48.85651397705078
# global_step=337552, episodic_return=-45.85996627807617
# global_step=337936, episodic_return=-192.53158569335938
# global_step=338000, episodic_return=-66.53138732910156
# global_step=338128, episodic_return=-66.40726470947266
# global_step=338336, episodic_return=-78.650146484375
# global_step=338432, episodic_return=-136.9320068359375
# global_step=338720, episodic_return=-116.86055755615234
# global_step=338768, episodic_return=-77.77623748779297
# global_step=338816, episodic_return=-61.75965118408203
# global_step=339072, episodic_return=-67.98727416992188
# global_step=339232, episodic_return=-52.88277053833008
# global_step=339280, episodic_return=-128.6319580078125
# global_step=339328, episodic_return=-41.22310256958008
# global_step=339584, episodic_return=-80.7472915649414
# global_step=339744, episodic_return=-63.285030364990234
# global_step=339936, episodic_return=-188.65345764160156
# global_step=339968, episodic_return=-39.67486572265625
# global_step=340192, episodic_return=-189.84469604492188
# global_step=340320, episodic_return=-58.37228012084961
# global_step=340384, episodic_return=-65.20713806152344
# global_step=340416, episodic_return=-98.44424438476562
# global_step=340512, episodic_return=-22.904129028320312
# global_step=341312, episodic_return=-129.76708984375
# global_step=341424, episodic_return=-79.13604736328125
# global_step=341440, episodic_return=-104.90928649902344
# global_step=341456, episodic_return=-104.06378936767578
# global_step=341552, episodic_return=-83.83417510986328
# global_step=341568, episodic_return=-233.00360107421875
# global_step=341648, episodic_return=-100.57244873046875
# global_step=341904, episodic_return=-72.89083862304688
# global_step=341984, episodic_return=-173.39183044433594
# global_step=342048, episodic_return=-268.7275390625
# global_step=342096, episodic_return=30.021728515625
# global_step=342144, episodic_return=-101.8843765258789
# global_step=342672, episodic_return=-87.28189849853516
# global_step=342752, episodic_return=-17.39368438720703
# global_step=342848, episodic_return=-10.692626953125
# global_step=342896, episodic_return=-128.2220458984375
# global_step=343008, episodic_return=-41.10903549194336
# global_step=343168, episodic_return=-127.84781646728516
# global_step=343344, episodic_return=-44.160823822021484
# global_step=343712, episodic_return=-47.173763275146484
# global_step=343792, episodic_return=-102.42825317382812
# global_step=343904, episodic_return=-100.30989837646484
# SPS: 3066
# global_step=344144, episodic_return=-140.83424377441406
# global_step=344176, episodic_return=-267.0875549316406
# global_step=344272, episodic_return=-59.911983489990234
# global_step=344480, episodic_return=-75.42947387695312
# global_step=344512, episodic_return=-94.95223236083984
# global_step=344624, episodic_return=-61.469940185546875
# global_step=344656, episodic_return=-117.01303100585938
# global_step=344800, episodic_return=-137.431884765625
# global_step=345200, episodic_return=-91.26077270507812
# global_step=345296, episodic_return=-57.78388595581055
# global_step=345504, episodic_return=-124.3931884765625
# global_step=345552, episodic_return=-139.7643280029297
# global_step=345600, episodic_return=-94.02145385742188
# global_step=345680, episodic_return=-47.0229606628418
# global_step=345744, episodic_return=-108.18383026123047
# global_step=345776, episodic_return=18.431983947753906
# global_step=345824, episodic_return=-75.7424087524414
# global_step=345968, episodic_return=-29.934982299804688
# global_step=346176, episodic_return=-105.20520782470703
# global_step=346496, episodic_return=-59.037593841552734
# global_step=346512, episodic_return=-34.32734680175781
# global_step=346672, episodic_return=-102.49068450927734
# global_step=346960, episodic_return=-59.95241165161133
# global_step=346992, episodic_return=-97.5107650756836
# global_step=347056, episodic_return=-83.19989013671875
# global_step=347248, episodic_return=-120.69667053222656
# global_step=347344, episodic_return=-98.7759780883789
# global_step=347408, episodic_return=-18.063980102539062
# global_step=347520, episodic_return=-90.48955535888672
# global_step=347664, episodic_return=-32.68206787109375
# global_step=347696, episodic_return=-245.584716796875
# global_step=347984, episodic_return=-105.40990447998047
# global_step=348272, episodic_return=-93.39252471923828
# global_step=348384, episodic_return=-42.44832992553711
# global_step=348432, episodic_return=-99.5626449584961
# global_step=348512, episodic_return=-105.93029022216797
# global_step=348704, episodic_return=-111.80769348144531
# global_step=348720, episodic_return=-81.92414855957031
# global_step=348752, episodic_return=-36.43340301513672
# global_step=348896, episodic_return=-90.4023208618164
# global_step=348928, episodic_return=-105.26313018798828
# global_step=349072, episodic_return=-174.18051147460938
# global_step=349104, episodic_return=-75.86929321289062
# global_step=349392, episodic_return=-91.986572265625
# global_step=349632, episodic_return=-55.39474868774414
# global_step=349664, episodic_return=-89.73096466064453
# global_step=349824, episodic_return=-92.16996002197266
# global_step=349904, episodic_return=-96.42453002929688
# global_step=349920, episodic_return=-421.3548889160156
# global_step=350256, episodic_return=-34.325645446777344
# global_step=350272, episodic_return=-57.578094482421875
# global_step=350320, episodic_return=-103.08477020263672
# global_step=350336, episodic_return=-52.601104736328125
# global_step=350464, episodic_return=-113.01113891601562
# global_step=350608, episodic_return=-52.15652847290039
# global_step=350640, episodic_return=-46.827781677246094
# global_step=350848, episodic_return=64.6210708618164
# global_step=350864, episodic_return=-34.46281433105469
# global_step=350896, episodic_return=-253.06179809570312
# global_step=351184, episodic_return=-111.7925796508789
# global_step=351296, episodic_return=-31.96642303466797
# global_step=351712, episodic_return=-21.185165405273438
# global_step=351744, episodic_return=-93.45836639404297
# global_step=351760, episodic_return=-76.26763916015625
# global_step=351968, episodic_return=-85.12226104736328
# global_step=352080, episodic_return=-91.576171875
# global_step=352112, episodic_return=-18.37073516845703
# global_step=352144, episodic_return=-66.98500061035156
# global_step=352176, episodic_return=-85.87704467773438
# SPS: 3054
# global_step=352416, episodic_return=-153.00254821777344
# global_step=352656, episodic_return=-92.90518188476562
# global_step=352720, episodic_return=-67.20516967773438
# global_step=352848, episodic_return=-95.35823822021484
# global_step=352880, episodic_return=-74.12736511230469
# global_step=353056, episodic_return=20.532325744628906
# global_step=353152, episodic_return=-96.39583587646484
# global_step=353184, episodic_return=-232.00595092773438
# global_step=353440, episodic_return=-103.76069641113281
# global_step=353456, episodic_return=-49.27455520629883
# global_step=353584, episodic_return=-102.2771224975586
# global_step=353632, episodic_return=-76.09617614746094
# global_step=353872, episodic_return=-116.21094512939453
# global_step=353984, episodic_return=-118.09441375732422
# global_step=354000, episodic_return=-82.52544403076172
# global_step=354112, episodic_return=-210.31033325195312
# global_step=354320, episodic_return=-72.43949890136719
# global_step=354448, episodic_return=-34.895599365234375
# global_step=354480, episodic_return=-60.628841400146484
# global_step=354656, episodic_return=-82.71974182128906
# global_step=354896, episodic_return=-154.20677185058594
# global_step=354960, episodic_return=-70.1849365234375
# global_step=355040, episodic_return=-80.3131332397461
# global_step=355072, episodic_return=-76.71377563476562
# global_step=355152, episodic_return=-230.894287109375
# global_step=355664, episodic_return=-97.64469909667969
# global_step=355728, episodic_return=18.683059692382812
# global_step=355872, episodic_return=-262.56280517578125
# global_step=355904, episodic_return=-140.28236389160156
# global_step=356032, episodic_return=-97.01607513427734
# global_step=356256, episodic_return=-37.68134307861328
# global_step=356272, episodic_return=-100.8859634399414
# global_step=356448, episodic_return=-33.958290100097656
# global_step=356480, episodic_return=-63.31106948852539
# global_step=356528, episodic_return=-267.8979797363281
# global_step=356624, episodic_return=-109.95545196533203
# global_step=356896, episodic_return=-152.05010986328125
# global_step=356976, episodic_return=-114.83064270019531
# global_step=357008, episodic_return=-61.70991134643555
# global_step=357072, episodic_return=-147.72207641601562
# global_step=357184, episodic_return=-70.88533020019531
# global_step=357264, episodic_return=-78.14959716796875
# global_step=357568, episodic_return=-121.19754791259766
# global_step=357920, episodic_return=-82.21426391601562
# global_step=357968, episodic_return=-83.2273178100586
# global_step=358128, episodic_return=-65.74488067626953
# global_step=358288, episodic_return=-245.47694396972656
# global_step=358320, episodic_return=-98.80064392089844
# global_step=358384, episodic_return=-32.22978973388672
# global_step=358592, episodic_return=-53.35551834106445
# global_step=358688, episodic_return=-98.52569580078125
# global_step=358912, episodic_return=-40.3615608215332
# global_step=359184, episodic_return=43.01795959472656
# global_step=359200, episodic_return=-80.014892578125
# global_step=359312, episodic_return=-104.11905670166016
# global_step=359328, episodic_return=-77.85618591308594
# global_step=359536, episodic_return=-37.14816665649414
# global_step=359936, episodic_return=-58.71272659301758
# global_step=360032, episodic_return=-67.49452209472656
# global_step=360128, episodic_return=-175.42208862304688
# global_step=360272, episodic_return=-38.4438591003418
# global_step=360368, episodic_return=-46.25429153442383
# global_step=360384, episodic_return=-89.6260757446289
# global_step=360416, episodic_return=-10.737075805664062
# SPS: 3057
# global_step=360496, episodic_return=-67.52676391601562
# global_step=360512, episodic_return=-98.1722412109375
# global_step=360592, episodic_return=-117.48008728027344
# global_step=360736, episodic_return=-106.14714813232422
# global_step=361088, episodic_return=-72.78412628173828
# global_step=361184, episodic_return=-164.18692016601562
# global_step=361328, episodic_return=-164.95401000976562
# global_step=361360, episodic_return=-68.8094482421875
# global_step=361568, episodic_return=-34.112701416015625
# global_step=361872, episodic_return=-175.654052734375
# global_step=361888, episodic_return=-54.6124153137207
# global_step=362048, episodic_return=-227.07916259765625
# global_step=362064, episodic_return=-31.501693725585938
# global_step=362144, episodic_return=-242.8459014892578
# global_step=362256, episodic_return=-88.7525634765625
# global_step=362272, episodic_return=-76.51360321044922
# global_step=362400, episodic_return=-73.61428833007812
# global_step=362624, episodic_return=-16.927749633789062
# global_step=362640, episodic_return=-62.66013717651367
# global_step=362656, episodic_return=-83.3741455078125
# global_step=362800, episodic_return=-88.6890640258789
# global_step=362816, episodic_return=-60.478355407714844
# global_step=362960, episodic_return=-62.911354064941406
# global_step=363152, episodic_return=-80.24207305908203
# global_step=363456, episodic_return=-73.4375228881836
# global_step=363472, episodic_return=-25.030296325683594
# global_step=363744, episodic_return=-61.25007629394531
# global_step=363792, episodic_return=-188.27276611328125
# global_step=363904, episodic_return=-89.72195434570312
# global_step=364016, episodic_return=-23.649765014648438
# global_step=364064, episodic_return=-89.29032135009766
# global_step=364208, episodic_return=-57.3670654296875
# global_step=364224, episodic_return=-68.11754608154297
# global_step=364752, episodic_return=-48.32743453979492
# global_step=364768, episodic_return=-194.09078979492188
# global_step=364896, episodic_return=-151.4697265625
# global_step=364944, episodic_return=-113.9715576171875
# global_step=364976, episodic_return=-20.609481811523438
# global_step=364992, episodic_return=-26.381736755371094
# global_step=365104, episodic_return=-100.99095916748047
# global_step=365136, episodic_return=-166.08938598632812
# global_step=365600, episodic_return=-53.695194244384766
# global_step=366048, episodic_return=-57.33773422241211
# global_step=366128, episodic_return=-206.6042022705078
# global_step=366224, episodic_return=-227.03262329101562
# global_step=366448, episodic_return=-31.46825408935547
# global_step=366512, episodic_return=-146.21090698242188
# global_step=366560, episodic_return=-136.02130126953125
# global_step=366880, episodic_return=-95.12799835205078
# global_step=367152, episodic_return=-122.34070587158203
# ...
# global_step=955520, episodic_return=-45.67981719970703
# global_step=955664, episodic_return=-56.589229583740234
# global_step=955904, episodic_return=-29.907211303710938
# global_step=955984, episodic_return=-52.75608825683594
# global_step=956160, episodic_return=-56.15659713745117
# global_step=956560, episodic_return=-32.299034118652344
# global_step=956848, episodic_return=-1.8128280639648438
# global_step=957296, episodic_return=-65.13706970214844
# global_step=957328, episodic_return=-106.5582275390625
# global_step=957600, episodic_return=2.43634033203125
# global_step=957648, episodic_return=-71.3736572265625
# global_step=957696, episodic_return=-94.66795349121094
# global_step=957776, episodic_return=-12.642242431640625
# global_step=958032, episodic_return=-181.77120971679688
# global_step=958288, episodic_return=-157.44781494140625
# global_step=958320, episodic_return=-17.1641845703125
# SPS: 2600
# global_step=958528, episodic_return=-82.97689819335938
# global_step=958736, episodic_return=-27.814376831054688
# global_step=958800, episodic_return=-6.312469482421875
# global_step=959024, episodic_return=-25.985557556152344
# global_step=959456, episodic_return=-40.272464752197266
# global_step=959808, episodic_return=-110.04017639160156
# global_step=960000, episodic_return=-224.91282653808594
# global_step=960096, episodic_return=-18.189697265625
# global_step=960112, episodic_return=-48.39065933227539
# global_step=960144, episodic_return=-30.317459106445312
# global_step=960224, episodic_return=-60.10469436645508
# global_step=960496, episodic_return=-106.33425903320312
# global_step=960640, episodic_return=-46.01166534423828
# global_step=961216, episodic_return=21.408203125
# global_step=961232, episodic_return=-4.488655090332031
# global_step=961264, episodic_return=-43.77210235595703
# global_step=961280, episodic_return=-16.602088928222656
# global_step=961792, episodic_return=-296.7890625
# global_step=961968, episodic_return=-77.87672424316406
# global_step=961984, episodic_return=-30.30413055419922
# global_step=962208, episodic_return=-42.87257766723633
# global_step=962384, episodic_return=-96.03739929199219
# global_step=962432, episodic_return=-60.850608825683594
# global_step=962528, episodic_return=-125.7577896118164
# global_step=962624, episodic_return=-19.39252471923828
# global_step=962752, episodic_return=-50.977718353271484
# global_step=963024, episodic_return=-86.30377197265625
# global_step=963184, episodic_return=-104.93956756591797
# global_step=963232, episodic_return=-72.61067962646484
# global_step=963424, episodic_return=-7.2686767578125
# global_step=963472, episodic_return=-35.9254150390625
# global_step=964016, episodic_return=-31.37360382080078
# global_step=964272, episodic_return=-4.626930236816406
# global_step=964624, episodic_return=-52.63798904418945
# global_step=964640, episodic_return=-22.55687713623047
# global_step=964848, episodic_return=-33.63842010498047
# global_step=965008, episodic_return=-108.05382537841797
# global_step=965072, episodic_return=-1.4116592407226562
# global_step=965136, episodic_return=-63.38077926635742
# global_step=965504, episodic_return=-143.07647705078125
# global_step=965520, episodic_return=13.14459228515625
# global_step=965568, episodic_return=-7.539664268493652
# global_step=965648, episodic_return=-48.688873291015625
# global_step=965712, episodic_return=-9.232872009277344
# global_step=966208, episodic_return=-31.249313354492188
# global_step=966656, episodic_return=-179.66476440429688
# SPS: 2597
# global_step=966672, episodic_return=-19.5142822265625
# global_step=967168, episodic_return=9.5203857421875
# global_step=967248, episodic_return=-47.68788146972656
# global_step=967376, episodic_return=-165.0590362548828
# global_step=967408, episodic_return=-0.44458770751953125
# global_step=967552, episodic_return=-49.49207305908203
# global_step=967648, episodic_return=-86.03785705566406
# global_step=967680, episodic_return=-55.372230529785156
# global_step=967856, episodic_return=-31.385833740234375
# global_step=968272, episodic_return=-221.3939971923828
# global_step=968384, episodic_return=-62.405517578125
# global_step=968480, episodic_return=-33.00608825683594
# global_step=968640, episodic_return=-18.38018798828125
# global_step=968848, episodic_return=-57.06696701049805
# global_step=969264, episodic_return=-153.40203857421875
# global_step=969360, episodic_return=4.2243194580078125
# global_step=969600, episodic_return=-4.052085876464844
# global_step=969824, episodic_return=14.23773193359375
# global_step=969904, episodic_return=-28.242218017578125
# global_step=969952, episodic_return=-22.567657470703125
# global_step=969968, episodic_return=9.505683898925781
# global_step=970048, episodic_return=-30.355133056640625
# global_step=970096, episodic_return=-12.533027648925781
# global_step=970192, episodic_return=-24.762107849121094
# global_step=970336, episodic_return=-46.859004974365234
# global_step=970576, episodic_return=-151.01632690429688
# global_step=971184, episodic_return=-83.09217834472656
# global_step=971280, episodic_return=-80.34303283691406
# global_step=971344, episodic_return=9.584999084472656
# global_step=971440, episodic_return=-59.783897399902344
# global_step=971600, episodic_return=-39.56867980957031
# global_step=971648, episodic_return=-151.5750274658203
# global_step=972208, episodic_return=-140.4390411376953
# global_step=972352, episodic_return=-19.585678100585938
# global_step=972800, episodic_return=-72.70924377441406
# global_step=972912, episodic_return=-24.153244018554688
# global_step=972944, episodic_return=-70.19839477539062
# global_step=972960, episodic_return=-33.935089111328125
# global_step=973440, episodic_return=-3.5280685424804688
# global_step=973472, episodic_return=-71.53314208984375
# global_step=973776, episodic_return=-56.82432556152344
# global_step=973872, episodic_return=-181.57952880859375
# global_step=973888, episodic_return=0.5688629150390625
# global_step=974176, episodic_return=11.844123840332031
# SPS: 2597
# global_step=975024, episodic_return=-14.940902709960938
# global_step=975136, episodic_return=-5.785133361816406
# global_step=975184, episodic_return=13.087348937988281
# global_step=975296, episodic_return=-78.46759033203125
# global_step=975536, episodic_return=-25.986221313476562
# global_step=975600, episodic_return=-0.3747100830078125
# global_step=976224, episodic_return=-45.20782470703125
# global_step=976352, episodic_return=-74.88618469238281
# global_step=976384, episodic_return=-23.489051818847656
# global_step=976400, episodic_return=-28.104942321777344
# global_step=976640, episodic_return=-35.43681335449219
# global_step=977136, episodic_return=-140.7063751220703
# global_step=977184, episodic_return=-55.74455642700195
# global_step=977296, episodic_return=26.869895935058594
# global_step=977312, episodic_return=-108.0307388305664
# global_step=977680, episodic_return=3.627471923828125
# global_step=977696, episodic_return=-61.33857345581055
# global_step=977712, episodic_return=-157.32704162597656
# global_step=978544, episodic_return=-2.8557510375976562
# global_step=978560, episodic_return=32.0823974609375
# global_step=978816, episodic_return=-74.9513931274414
# global_step=978896, episodic_return=-56.72553634643555
# global_step=978928, episodic_return=-60.19817352294922
# global_step=979088, episodic_return=-76.26467895507812
# global_step=979296, episodic_return=-59.805580139160156
# global_step=979520, episodic_return=-8.849510192871094
# global_step=979680, episodic_return=-66.08485412597656
# global_step=979744, episodic_return=-17.488685607910156
# global_step=979792, episodic_return=-203.5242919921875
# global_step=979824, episodic_return=-40.12578201293945
# global_step=979936, episodic_return=-106.21588897705078
# global_step=980128, episodic_return=-5.126289367675781
# global_step=980832, episodic_return=11.954582214355469
# global_step=980896, episodic_return=12.026077270507812
# global_step=981008, episodic_return=42.53858947753906
# global_step=981040, episodic_return=-110.58116149902344
# global_step=981264, episodic_return=-147.93853759765625
# global_step=981424, episodic_return=-125.00291442871094
# global_step=981456, episodic_return=-138.73776245117188
# global_step=981472, episodic_return=-181.48992919921875
# global_step=982096, episodic_return=-74.64871978759766
# global_step=982272, episodic_return=-85.69709777832031
# global_step=982432, episodic_return=-20.34313201904297
# global_step=982464, episodic_return=-159.44427490234375
# global_step=982608, episodic_return=45.981536865234375
# SPS: 2593
# global_step=983184, episodic_return=-133.7199249267578
# global_step=983216, episodic_return=25.22350311279297
# global_step=983328, episodic_return=-77.82022857666016
# global_step=983376, episodic_return=-20.94487762451172
# global_step=983424, episodic_return=-25.88422393798828
# global_step=983456, episodic_return=-33.46369934082031
# global_step=983504, episodic_return=-113.96588897705078
# global_step=984480, episodic_return=-60.74724578857422
# global_step=984576, episodic_return=-172.54696655273438
# global_step=984848, episodic_return=-79.90214538574219
# global_step=984960, episodic_return=-62.278724670410156
# global_step=985280, episodic_return=-40.85966491699219
# global_step=985536, episodic_return=-85.92381286621094
# global_step=985632, episodic_return=-41.72921371459961
# global_step=985760, episodic_return=-119.60150146484375
# global_step=985776, episodic_return=-53.79521560668945
# global_step=986176, episodic_return=-42.5918083190918
# global_step=986240, episodic_return=-65.0286865234375
# global_step=986320, episodic_return=-75.59010314941406
# global_step=986464, episodic_return=-18.19794464111328
# global_step=986496, episodic_return=-16.361099243164062
# global_step=986656, episodic_return=3.9984512329101562
# global_step=986704, episodic_return=-80.36190795898438
# global_step=986720, episodic_return=-84.00357818603516
# global_step=987056, episodic_return=-55.44198989868164
# global_step=987280, episodic_return=-51.100181579589844
# global_step=987664, episodic_return=-68.64957427978516
# global_step=988032, episodic_return=-38.64276885986328
# global_step=988160, episodic_return=-1.052093505859375
# global_step=988512, episodic_return=-85.72407531738281
# global_step=988528, episodic_return=-139.82135009765625
# global_step=988608, episodic_return=1.9472579956054688
# global_step=988624, episodic_return=-122.22752380371094
# global_step=988768, episodic_return=-300.63372802734375
# global_step=988800, episodic_return=10.921621322631836
# global_step=988832, episodic_return=-51.61436080932617
# global_step=989024, episodic_return=25.3641357421875
# global_step=989488, episodic_return=-26.723655700683594
# global_step=989600, episodic_return=-15.925750732421875
# global_step=989776, episodic_return=-66.76258850097656
# global_step=989920, episodic_return=-64.10670471191406
# global_step=990560, episodic_return=33.02183532714844
# global_step=990640, episodic_return=0.172607421875
# global_step=990672, episodic_return=-147.0013885498047
# global_step=990752, episodic_return=-34.05065155029297
# global_step=990832, episodic_return=-7.51617431640625
# global_step=991152, episodic_return=20.46863555908203
# global_step=991216, episodic_return=-66.92800903320312
# SPS: 2587
# global_step=991360, episodic_return=-199.66310119628906
# global_step=991424, episodic_return=-20.965179443359375
# global_step=991760, episodic_return=-145.28663635253906
# global_step=991856, episodic_return=-18.130325317382812
# global_step=991952, episodic_return=-190.92202758789062
# global_step=992016, episodic_return=-41.10535430908203
# global_step=992144, episodic_return=-81.20112609863281
# global_step=992272, episodic_return=-4.257926940917969
# global_step=992928, episodic_return=-18.741653442382812
# global_step=993392, episodic_return=-177.68482971191406
# global_step=993728, episodic_return=-88.8016357421875
# global_step=993808, episodic_return=24.84929656982422
# global_step=993968, episodic_return=-36.44425964355469
# global_step=994032, episodic_return=-6.098762512207031
# global_step=994064, episodic_return=-7.211219787597656
# global_step=994096, episodic_return=-31.720237731933594
# global_step=994128, episodic_return=-96.53138732910156
# global_step=994496, episodic_return=5.626136779785156
# global_step=994624, episodic_return=-37.1966438293457
# global_step=994688, episodic_return=-90.44053649902344
# global_step=994880, episodic_return=-53.084007263183594
# global_step=995040, episodic_return=-98.03065490722656
# global_step=995520, episodic_return=-123.99435424804688
# global_step=995552, episodic_return=-20.513534545898438
# global_step=995584, episodic_return=-58.38889694213867
# global_step=995792, episodic_return=-38.28810119628906
# global_step=996176, episodic_return=-163.7768096923828
# global_step=996288, episodic_return=-15.654136657714844
# global_step=996576, episodic_return=-73.63424682617188
# global_step=997200, episodic_return=-92.42684173583984
# global_step=997264, episodic_return=24.067279815673828
# global_step=997312, episodic_return=-29.472442626953125
# global_step=997328, episodic_return=-44.115203857421875
# global_step=997392, episodic_return=-98.06450653076172
# global_step=997520, episodic_return=-67.21969604492188
# global_step=997728, episodic_return=-119.20092010498047
# global_step=997888, episodic_return=-30.05040740966797
# global_step=998112, episodic_return=-145.96768188476562
# global_step=998576, episodic_return=-51.50302505493164
# global_step=998592, episodic_return=-31.37787628173828
# global_step=998928, episodic_return=-79.35611724853516
# global_step=999104, episodic_return=-55.88748550415039
# global_step=999328, episodic_return=-177.85745239257812
# global_step=999360, episodic_return=6.586997985839844
# global_step=999392, episodic_return=-166.88565063476562
# SPS: 2584
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ℹ Pushing repo Chiz/ppo-LunarLander-v2 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...16860.86cf83882442.9173.0: 100% 972k/972k [00:00<?, ?B/s]
#
#
#   /tmp/tmpqihprnk3/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#   ...16860.86cf83882442.9173.0: 100% 972k/972k [00:00<?, ?B/s]
#
#
# Processing Files (2 / 2)      : 100% 1.02M/1.02M [00:00<00:00, 1.16MB/s, 1.69MB/s  ]
# New Data Upload               : 100% 1.02M/1.02M [00:00<00:00, 1.16MB/s, 1.69MB/s  ]
#
#   ...16860.86cf83882442.9173.0: 100% 972k/972k [00:00<?, ?B/s]
#
#
#   /tmp/tmpqihprnk3/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#   ...16860.86cf83882442.9173.0: 100% 972k/972k [00:00<?, ?B/s]
#
#
# Processing Files (2 / 2)      : 100% 1.02M/1.02M [00:01<00:00, 943kB/s, 1.27MB/s  ]
# New Data Upload               : 100% 1.02M/1.02M [00:01<00:00, 943kB/s, 1.27MB/s  ]
#   ...16860.86cf83882442.9173.0: 100% 972k/972k [00:00<?, ?B/s]
#   /tmp/tmpqihprnk3/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Chiz/ppo-LunarLander-v2/commit/8babea4abc3c6ac44f07e433e1e43c57a3f1df44

# %% [markdown]
# ### **Huggingface mean_reward on LunarLander-v2 self-reported: -69.14 +/- 46.39**

# %%
# !python ppo.py \
  --env-id="LunarLander-v2" \
  --repo-id="Chiz/ppo-LunarLander-v2" \
  --total-timesteps=1000000 \
  --learning-rate=2.5e-4 \
  --num-envs=16 \
  --num-steps=1024 \
  --gamma=0.99 \
  --gae-lambda=0.95 \
  --num-minibatches=4 \
  --update-epochs=10 \
  --ent-coef=0.01 \
  --anneal-lr=True
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# 2026-02-15 01:12:01.975394: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771117921.996150   13633 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771117922.003305   13633 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771117922.020830   13633 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771117922.020856   13633 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771117922.020860   13633 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771117922.020864   13633 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 01:12:02.025501: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# global_step=1136, episodic_return=-120.37911224365234
# global_step=1168, episodic_return=-88.90178680419922
# global_step=1200, episodic_return=-125.00140380859375
# global_step=1344, episodic_return=-404.14306640625
# global_step=1376, episodic_return=-70.5389633178711
# global_step=1536, episodic_return=-140.92999267578125
# global_step=1616, episodic_return=-242.15333557128906
# global_step=1648, episodic_return=-92.00662231445312
# global_step=1680, episodic_return=-109.83496856689453
# global_step=1696, episodic_return=-170.81808471679688
# global_step=1888, episodic_return=-320.47113037109375
# global_step=1904, episodic_return=-81.00199127197266
# global_step=1936, episodic_return=-20.284835815429688
# global_step=2016, episodic_return=-375.2597961425781
# global_step=2048, episodic_return=-71.44508361816406
# global_step=2416, episodic_return=-102.25274658203125
# global_step=2784, episodic_return=-359.5760192871094
# global_step=2800, episodic_return=-95.84423065185547
# global_step=2832, episodic_return=-265.513671875
# global_step=2912, episodic_return=-222.11920166015625
# global_step=2928, episodic_return=-81.24649047851562
# global_step=2960, episodic_return=-206.37762451171875
# global_step=3136, episodic_return=-81.619140625
# global_step=3280, episodic_return=-331.29351806640625
# global_step=3344, episodic_return=-207.9798583984375
# global_step=3376, episodic_return=-123.97432708740234
# global_step=3392, episodic_return=-479.1644592285156
# global_step=3792, episodic_return=-169.76611328125
# global_step=3856, episodic_return=-94.81404876708984
# global_step=3872, episodic_return=-106.20765686035156
# global_step=3952, episodic_return=-224.209716796875
# global_step=4000, episodic_return=-130.58908081054688
# global_step=4208, episodic_return=-81.72651672363281
# global_step=4240, episodic_return=-117.05354309082031
# global_step=4320, episodic_return=-103.4632797241211
# global_step=4352, episodic_return=-229.77891540527344
# global_step=4544, episodic_return=-113.75259399414062
# global_step=4624, episodic_return=-205.71966552734375
# global_step=4656, episodic_return=-163.04998779296875
# global_step=4784, episodic_return=-540.876708984375
# global_step=4816, episodic_return=-350.6524963378906
# global_step=4832, episodic_return=-240.8679962158203
# global_step=4944, episodic_return=-104.04576873779297
# global_step=5136, episodic_return=-116.46452331542969
# global_step=5264, episodic_return=-223.84754943847656
# global_step=5280, episodic_return=-218.2301483154297
# global_step=5456, episodic_return=-67.10397338867188
# global_step=5616, episodic_return=-171.53079223632812
# global_step=5648, episodic_return=-188.77415466308594
# global_step=5696, episodic_return=-139.28335571289062
# global_step=5808, episodic_return=-263.79193115234375
# global_step=5856, episodic_return=-87.25646209716797
# global_step=5872, episodic_return=-59.67002487182617
# global_step=5952, episodic_return=-122.65647888183594
# global_step=6080, episodic_return=-297.56524658203125
# global_step=6096, episodic_return=-97.82431030273438
# global_step=6240, episodic_return=-101.09182739257812
# global_step=6320, episodic_return=-314.4579162597656
# global_step=6496, episodic_return=-57.691734313964844
# global_step=6560, episodic_return=-88.28770446777344
# global_step=6704, episodic_return=-52.97072982788086
# global_step=6784, episodic_return=-86.69527435302734
# global_step=6960, episodic_return=-80.48553466796875
# global_step=6992, episodic_return=-196.3870086669922
# global_step=7040, episodic_return=-242.6302947998047
# global_step=7136, episodic_return=-138.781982421875
# global_step=7216, episodic_return=-642.249755859375
# global_step=7264, episodic_return=-153.7117919921875
# global_step=7296, episodic_return=-124.68617248535156
# global_step=7376, episodic_return=-317.15875244140625
# global_step=7488, episodic_return=-199.86155700683594
# global_step=7632, episodic_return=-236.80755615234375
# global_step=7712, episodic_return=-89.87983703613281
# global_step=8112, episodic_return=-208.70953369140625
# global_step=8160, episodic_return=-57.72515869140625
# global_step=8336, episodic_return=-109.95030975341797
# global_step=8384, episodic_return=-134.9935302734375
# global_step=8448, episodic_return=-260.76080322265625
# global_step=8528, episodic_return=-195.89410400390625
# global_step=8672, episodic_return=-163.92193603515625
# global_step=8784, episodic_return=-310.9855651855469
# global_step=8880, episodic_return=-266.99957275390625
# global_step=9024, episodic_return=-185.00482177734375
# global_step=9088, episodic_return=-162.64779663085938
# global_step=9376, episodic_return=-249.2372283935547
# global_step=9472, episodic_return=-139.20486450195312
# global_step=9680, episodic_return=-167.8804931640625
# global_step=9760, episodic_return=-85.0106201171875
# global_step=9824, episodic_return=-240.51705932617188
# global_step=9920, episodic_return=-219.35641479492188
# global_step=9936, episodic_return=-1.0964431762695312
# global_step=9952, episodic_return=-396.1626281738281
# global_step=10080, episodic_return=-12.033546447753906
# global_step=10096, episodic_return=-300.6098327636719
# global_step=10128, episodic_return=-24.920989990234375
# global_step=10160, episodic_return=-99.00643157958984
# global_step=10432, episodic_return=-74.77631378173828
# global_step=10528, episodic_return=-243.7557373046875
# global_step=10688, episodic_return=-391.9200439453125
# global_step=10736, episodic_return=-156.596435546875
# global_step=10816, episodic_return=-69.18864440917969
# global_step=11024, episodic_return=-79.97271728515625
# global_step=11136, episodic_return=-92.91183471679688
# global_step=11168, episodic_return=-85.56299591064453
# global_step=11232, episodic_return=-95.50347900390625
# global_step=11328, episodic_return=-416.19183349609375
# global_step=11392, episodic_return=-329.7781066894531
# global_step=11616, episodic_return=-121.60391998291016
# global_step=11680, episodic_return=-167.78363037109375
# global_step=11712, episodic_return=-145.77471923828125
# global_step=11728, episodic_return=-134.13372802734375
# global_step=11840, episodic_return=-81.71385192871094
# global_step=11984, episodic_return=-260.58685302734375
# global_step=12064, episodic_return=-291.5769348144531
# global_step=12176, episodic_return=-123.21067810058594
# global_step=12272, episodic_return=-92.99011993408203
# global_step=12336, episodic_return=-219.3701934814453
# global_step=12656, episodic_return=-71.37358856201172
# global_step=12720, episodic_return=-418.7044982910156
# global_step=12784, episodic_return=-97.78112030029297
# global_step=12848, episodic_return=-100.34900665283203
# global_step=12960, episodic_return=-248.6029815673828
# global_step=13088, episodic_return=-130.0629119873047
# global_step=13136, episodic_return=7.758018493652344
# global_step=13216, episodic_return=-104.8854751586914
# global_step=13376, episodic_return=-181.7991943359375
# global_step=13408, episodic_return=-297.76116943359375
# global_step=13504, episodic_return=-118.56736755371094
# global_step=13616, episodic_return=-206.1214599609375
# global_step=13888, episodic_return=-197.9373779296875
# global_step=13952, episodic_return=-365.2164611816406
# global_step=13968, episodic_return=-142.75613403320312
# global_step=14016, episodic_return=-93.41387176513672
# global_step=14048, episodic_return=-108.16592407226562
# global_step=14080, episodic_return=-218.28460693359375
# global_step=14096, episodic_return=-71.71263885498047
# global_step=14176, episodic_return=-118.36214447021484
# global_step=14240, episodic_return=-112.15415954589844
# global_step=14480, episodic_return=-370.445556640625
# global_step=14528, episodic_return=-220.95297241210938
# global_step=14640, episodic_return=-68.75447845458984
# global_step=14656, episodic_return=-142.70797729492188
# global_step=14864, episodic_return=-76.15425109863281
# global_step=15024, episodic_return=-111.20521545410156
# global_step=15184, episodic_return=-122.27755737304688
# global_step=15376, episodic_return=-240.9208526611328
# global_step=15392, episodic_return=-341.53466796875
# global_step=15424, episodic_return=-119.73259735107422
# global_step=15472, episodic_return=-324.53778076171875
# global_step=15536, episodic_return=-125.19328308105469
# global_step=15552, episodic_return=-525.8367919921875
# global_step=15696, episodic_return=-128.2164306640625
# global_step=15840, episodic_return=-88.35011291503906
# global_step=16032, episodic_return=-79.16796875
# global_step=16080, episodic_return=-188.69668579101562
# global_step=16112, episodic_return=-319.3144226074219
# global_step=16240, episodic_return=-113.58850860595703
# global_step=16288, episodic_return=-205.43487548828125
# SPS: 2844
# global_step=16592, episodic_return=-135.30108642578125
# global_step=16656, episodic_return=-46.108341217041016
# global_step=16704, episodic_return=-118.26046752929688
# global_step=16896, episodic_return=-110.50311279296875
# global_step=16960, episodic_return=-211.28558349609375
# global_step=17104, episodic_return=-365.26715087890625
# global_step=17200, episodic_return=-120.9567642211914
# global_step=17248, episodic_return=-445.4554443359375
# global_step=17312, episodic_return=-466.1138916015625
# global_step=17504, episodic_return=-217.80633544921875
# global_step=17520, episodic_return=-581.89501953125
# global_step=17648, episodic_return=-147.14320373535156
# global_step=17920, episodic_return=-144.24072265625
# global_step=18144, episodic_return=-377.9192199707031
# global_step=18192, episodic_return=-308.278076171875
# global_step=18320, episodic_return=-119.95604705810547
# global_step=18400, episodic_return=-61.524105072021484
# global_step=18432, episodic_return=-62.050106048583984
# global_step=18480, episodic_return=-118.34522247314453
# global_step=18592, episodic_return=-105.30187225341797
# global_step=18656, episodic_return=-137.46282958984375
# global_step=18784, episodic_return=-342.188720703125
# global_step=18848, episodic_return=-96.41785430908203
# global_step=18976, episodic_return=-114.93775939941406
# global_step=19248, episodic_return=-134.1559600830078
# global_step=19296, episodic_return=-197.90928649902344
# global_step=19424, episodic_return=-295.1940612792969
# global_step=19536, episodic_return=-185.84649658203125
# global_step=19584, episodic_return=-38.82991409301758
# global_step=19776, episodic_return=-156.69186401367188
# global_step=19824, episodic_return=-82.20248413085938
# global_step=19856, episodic_return=-102.04076385498047
# global_step=19888, episodic_return=-83.96533966064453
# global_step=20016, episodic_return=-211.171875
# global_step=20080, episodic_return=-160.785400390625
# global_step=20272, episodic_return=-219.86474609375
# global_step=20432, episodic_return=-113.98143005371094
# global_step=20448, episodic_return=-162.83871459960938
# global_step=20480, episodic_return=-101.03119659423828
# global_step=20592, episodic_return=-84.01334381103516
# global_step=20752, episodic_return=-153.15130615234375
# global_step=20944, episodic_return=-280.60406494140625
# global_step=21088, episodic_return=-236.08929443359375
# global_step=21184, episodic_return=-389.9876708984375
# global_step=21344, episodic_return=-52.64537811279297
# global_step=21360, episodic_return=-332.083251953125
# global_step=21376, episodic_return=-102.29753875732422
# global_step=21584, episodic_return=-134.199951171875
# global_step=21632, episodic_return=-128.26890563964844
# global_step=21648, episodic_return=-87.843994140625
# global_step=21728, episodic_return=-162.3407745361328
# global_step=22016, episodic_return=-230.9186553955078
# global_step=22080, episodic_return=-303.47857666015625
# global_step=22112, episodic_return=-237.4211883544922
# global_step=22528, episodic_return=-342.6374206542969
# global_step=22560, episodic_return=-358.8780517578125
# global_step=22592, episodic_return=-46.005409240722656
# global_step=22720, episodic_return=-203.21282958984375
# global_step=22752, episodic_return=-315.5770263671875
# global_step=22880, episodic_return=-132.33993530273438
# global_step=22944, episodic_return=-403.9315490722656
# global_step=22992, episodic_return=31.413570404052734
# global_step=23120, episodic_return=-110.12108612060547
# global_step=23168, episodic_return=-120.74269104003906
# global_step=23184, episodic_return=-158.43853759765625
# global_step=23200, episodic_return=-120.48438262939453
# global_step=23216, episodic_return=-192.37034606933594
# global_step=23328, episodic_return=-76.75659942626953
# global_step=23712, episodic_return=-157.48809814453125
# global_step=23728, episodic_return=-72.00090789794922
# global_step=23856, episodic_return=-178.654052734375
# global_step=24192, episodic_return=-106.66815185546875
# global_step=24240, episodic_return=-101.21142578125
# global_step=24384, episodic_return=-212.617919921875
# global_step=24400, episodic_return=-112.9324951171875
# global_step=24480, episodic_return=-80.967041015625
# global_step=24576, episodic_return=-98.09911346435547
# global_step=24608, episodic_return=-80.35887908935547
# global_step=24640, episodic_return=-251.81649780273438
# global_step=24704, episodic_return=-207.2669677734375
# global_step=24720, episodic_return=-139.6387176513672
# global_step=24896, episodic_return=-361.7754211425781
# global_step=24992, episodic_return=-13.850616455078125
# global_step=25072, episodic_return=-92.47266387939453
# global_step=25296, episodic_return=-222.4365692138672
# global_step=25360, episodic_return=-99.22276306152344
# global_step=25472, episodic_return=-176.11996459960938
# global_step=25568, episodic_return=-97.60185241699219
# global_step=25648, episodic_return=-67.68253326416016
# global_step=25760, episodic_return=-197.01556396484375
# global_step=25792, episodic_return=-199.00799560546875
# global_step=25824, episodic_return=-354.70123291015625
# global_step=26048, episodic_return=-96.32469940185547
# global_step=26128, episodic_return=-142.34432983398438
# global_step=26144, episodic_return=5.9317779541015625
# global_step=26304, episodic_return=-86.33200073242188
# global_step=26336, episodic_return=-59.8730354309082
# global_step=26448, episodic_return=-137.80030822753906
# global_step=26592, episodic_return=-203.10482788085938
# global_step=26800, episodic_return=-176.02285766601562
# global_step=27008, episodic_return=-192.01434326171875
# global_step=27024, episodic_return=-129.59243774414062
# global_step=27104, episodic_return=-112.08525848388672
# global_step=27120, episodic_return=-183.8679962158203
# global_step=27232, episodic_return=-287.45428466796875
# global_step=27248, episodic_return=-167.88038635253906
# global_step=27520, episodic_return=-120.87799072265625
# global_step=27680, episodic_return=-126.19454193115234
# global_step=27968, episodic_return=-378.3050537109375
# global_step=28016, episodic_return=-364.7644958496094
# global_step=28128, episodic_return=-255.7632598876953
# global_step=28256, episodic_return=-372.035400390625
# global_step=28288, episodic_return=-70.08792877197266
# global_step=28336, episodic_return=-230.84237670898438
# global_step=28368, episodic_return=-81.3797607421875
# global_step=28416, episodic_return=-80.44913482666016
# global_step=28608, episodic_return=-175.518310546875
# global_step=28736, episodic_return=-304.88897705078125
# global_step=28816, episodic_return=-189.3001708984375
# global_step=28960, episodic_return=-58.54791259765625
# global_step=29296, episodic_return=-395.0091552734375
# global_step=29360, episodic_return=-96.15843200683594
# global_step=29408, episodic_return=-323.67236328125
# global_step=29488, episodic_return=-126.58145141601562
# global_step=29664, episodic_return=-227.15582275390625
# global_step=29760, episodic_return=-297.5184326171875
# global_step=29824, episodic_return=-122.44183349609375
# global_step=29872, episodic_return=-185.30795288085938
# global_step=29984, episodic_return=-129.24917602539062
# global_step=30000, episodic_return=-294.21185302734375
# global_step=30160, episodic_return=-128.7200164794922
# global_step=30176, episodic_return=-272.27166748046875
# global_step=30256, episodic_return=-232.17208862304688
# global_step=30448, episodic_return=-97.30646514892578
# global_step=30528, episodic_return=-196.989501953125
# global_step=30656, episodic_return=-85.72515106201172
# global_step=30800, episodic_return=-119.8568115234375
# global_step=30864, episodic_return=-149.63479614257812
# global_step=30896, episodic_return=-83.28044128417969
# global_step=30944, episodic_return=-106.7783203125
# global_step=31184, episodic_return=-110.64739227294922
# global_step=31264, episodic_return=-267.95782470703125
# global_step=31392, episodic_return=-273.62677001953125
# global_step=31456, episodic_return=-104.61170959472656
# global_step=31504, episodic_return=-98.79107666015625
# global_step=31600, episodic_return=-128.46470642089844
# global_step=31712, episodic_return=-201.53497314453125
# global_step=31872, episodic_return=-243.56069946289062
# global_step=31888, episodic_return=-345.4072570800781
# global_step=31936, episodic_return=-180.45530700683594
# global_step=32064, episodic_return=-78.69274139404297
# global_step=32416, episodic_return=-234.5126495361328
# global_step=32432, episodic_return=-285.64117431640625
# global_step=32464, episodic_return=-235.31724548339844
# global_step=32528, episodic_return=-56.61627960205078
# global_step=32672, episodic_return=-141.71084594726562
# global_step=32688, episodic_return=-130.4705810546875
# SPS: 2715
# global_step=32976, episodic_return=-123.22286987304688
# global_step=32992, episodic_return=-392.618408203125
# global_step=33024, episodic_return=-92.55516815185547
# global_step=33072, episodic_return=-380.1831359863281
# global_step=33104, episodic_return=-90.80165100097656
# global_step=33408, episodic_return=-286.6627502441406
# global_step=33456, episodic_return=-259.36151123046875
# global_step=33680, episodic_return=-143.03875732421875
# global_step=33744, episodic_return=-3.0549087524414062
# global_step=33760, episodic_return=-67.8333740234375
# global_step=33824, episodic_return=-110.25154113769531
# global_step=33856, episodic_return=-353.3073425292969
# global_step=34000, episodic_return=-223.14398193359375
# global_step=34112, episodic_return=-258.95806884765625
# global_step=34160, episodic_return=-184.66201782226562
# global_step=34336, episodic_return=-350.75244140625
# global_step=34480, episodic_return=-240.9551239013672
# global_step=34496, episodic_return=-170.6427001953125
# global_step=34784, episodic_return=-391.9488220214844
# global_step=34832, episodic_return=-100.76687622070312
# global_step=34960, episodic_return=-94.17639923095703
# global_step=35040, episodic_return=-136.87786865234375
# global_step=35152, episodic_return=-116.17239379882812
# global_step=35232, episodic_return=-189.06390380859375
# global_step=35312, episodic_return=-139.826416015625
# global_step=35472, episodic_return=-52.67341613769531
# global_step=35536, episodic_return=-96.383056640625
# global_step=35616, episodic_return=-490.56884765625
# global_step=35680, episodic_return=-302.4701843261719
# global_step=35872, episodic_return=-101.85417938232422
# global_step=36032, episodic_return=3.0536270141601562
# global_step=36096, episodic_return=-106.85877990722656
# global_step=36176, episodic_return=-221.7869873046875
# global_step=36224, episodic_return=-155.1969451904297
# global_step=36304, episodic_return=-197.83544921875
# global_step=36336, episodic_return=-107.49553680419922
# global_step=36368, episodic_return=-140.46705627441406
# global_step=36512, episodic_return=-249.2980499267578
# global_step=36640, episodic_return=-114.00540161132812
# global_step=36656, episodic_return=-96.58170318603516
# global_step=36832, episodic_return=-68.64985656738281
# global_step=36880, episodic_return=-412.9398193359375
# global_step=36976, episodic_return=-83.7806396484375
# global_step=37456, episodic_return=-92.9685287475586
# global_step=37472, episodic_return=-248.72276306152344
# global_step=37552, episodic_return=-389.977294921875
# global_step=37648, episodic_return=-148.6565399169922
# global_step=37744, episodic_return=-162.7625732421875
# global_step=37792, episodic_return=-256.1201171875
# global_step=37808, episodic_return=-120.09315490722656
# global_step=37856, episodic_return=-129.5935821533203
# global_step=37904, episodic_return=-152.7602081298828
# global_step=38000, episodic_return=-121.29423522949219
# global_step=38032, episodic_return=-89.03341674804688
# global_step=38224, episodic_return=-167.30361938476562
# global_step=38480, episodic_return=-315.6784362792969
# global_step=38688, episodic_return=-87.86408996582031
# global_step=38752, episodic_return=-117.595458984375
# global_step=38976, episodic_return=-164.53173828125
# global_step=39024, episodic_return=2.57012939453125
# global_step=39056, episodic_return=-94.50624084472656
# global_step=39072, episodic_return=-111.785888671875
# global_step=39168, episodic_return=-413.5806579589844
# global_step=39200, episodic_return=-108.08625793457031
# global_step=39264, episodic_return=-215.96908569335938
# global_step=39312, episodic_return=-230.3059539794922
# global_step=39328, episodic_return=-73.64826202392578
# global_step=39648, episodic_return=-253.44863891601562
# global_step=39904, episodic_return=-91.8087387084961
# global_step=40112, episodic_return=-165.55862426757812
# global_step=40128, episodic_return=-247.22677612304688
# global_step=40304, episodic_return=-195.5622100830078
# global_step=40336, episodic_return=-250.7618865966797
# global_step=40608, episodic_return=-119.7445297241211
# global_step=40688, episodic_return=-114.5071029663086
# global_step=40736, episodic_return=-150.67413330078125
# global_step=40752, episodic_return=-142.80438232421875
# global_step=40880, episodic_return=-220.73577880859375
# global_step=40912, episodic_return=-152.87118530273438
# global_step=41072, episodic_return=-73.93307495117188
# global_step=41120, episodic_return=-129.88192749023438
# global_step=41248, episodic_return=-74.81407928466797
# global_step=41408, episodic_return=-108.90190887451172
# global_step=41520, episodic_return=-290.6259765625
# global_step=41616, episodic_return=-114.96697235107422
# global_step=41648, episodic_return=-217.55047607421875
# global_step=41872, episodic_return=-115.64329528808594
# global_step=41904, episodic_return=-123.78266906738281
# global_step=41936, episodic_return=-68.02435302734375
# global_step=42112, episodic_return=-179.92291259765625
# global_step=42384, episodic_return=-135.54739379882812
# global_step=42544, episodic_return=-94.13053894042969
# global_step=42848, episodic_return=-94.35638427734375
# global_step=42960, episodic_return=-189.69505310058594
# global_step=43104, episodic_return=-111.21709442138672
# global_step=43248, episodic_return=-118.33724212646484
# global_step=43328, episodic_return=-100.77623748779297
# global_step=43344, episodic_return=-44.42979049682617
# global_step=43456, episodic_return=-245.98194885253906
# global_step=43536, episodic_return=-103.64530181884766
# global_step=43968, episodic_return=-515.1542358398438
# global_step=44000, episodic_return=21.63628387451172
# global_step=44144, episodic_return=-230.4014892578125
# global_step=44192, episodic_return=-58.14397048950195
# global_step=44224, episodic_return=-69.60592651367188
# global_step=44336, episodic_return=-128.51254272460938
# global_step=44416, episodic_return=-198.97250366210938
# global_step=44656, episodic_return=-145.94479370117188
# global_step=44784, episodic_return=-155.47694396972656
# global_step=44832, episodic_return=-83.99095153808594
# global_step=44864, episodic_return=-126.20308685302734
# global_step=44928, episodic_return=-90.23625183105469
# global_step=45216, episodic_return=-123.57347869873047
# global_step=45376, episodic_return=-96.97637176513672
# global_step=45392, episodic_return=-415.5896911621094
# global_step=45408, episodic_return=-82.67850494384766
# global_step=45584, episodic_return=-201.69473266601562
# global_step=45600, episodic_return=-64.97590637207031
# global_step=45648, episodic_return=-252.22813415527344
# global_step=45888, episodic_return=-181.09445190429688
# global_step=45936, episodic_return=-57.965877532958984
# global_step=46000, episodic_return=-209.9248046875
# global_step=46208, episodic_return=-97.80635070800781
# global_step=46304, episodic_return=-219.64761352539062
# global_step=46448, episodic_return=-104.08538055419922
# global_step=46480, episodic_return=-276.1014404296875
# global_step=46528, episodic_return=-78.99995422363281
# global_step=46672, episodic_return=-155.76251220703125
# global_step=46720, episodic_return=-126.38927459716797
# global_step=46832, episodic_return=-170.39352416992188
# global_step=46848, episodic_return=-92.68476104736328
# global_step=47008, episodic_return=-136.77023315429688
# global_step=47104, episodic_return=-350.6400146484375
# global_step=47200, episodic_return=-51.554569244384766
# global_step=47648, episodic_return=-99.07894897460938
# global_step=47664, episodic_return=-115.47425842285156
# global_step=47712, episodic_return=-114.65750122070312
# global_step=47824, episodic_return=-98.1023178100586
# global_step=47936, episodic_return=-234.9358367919922
# global_step=48000, episodic_return=-124.07891845703125
# global_step=48016, episodic_return=-152.19912719726562
# global_step=48048, episodic_return=-59.03553771972656
# global_step=48080, episodic_return=-63.90107727050781
# global_step=48160, episodic_return=-98.49259185791016
# global_step=48208, episodic_return=-112.2143325805664
# global_step=48304, episodic_return=-143.1802215576172
# global_step=48320, episodic_return=-108.45556640625
# global_step=48496, episodic_return=-112.05648803710938
# global_step=48800, episodic_return=-279.069580078125
# global_step=48896, episodic_return=-202.3585968017578
# global_step=49136, episodic_return=-182.21827697753906
# SPS: 2851
# global_step=49248, episodic_return=-64.44876098632812
# global_step=49280, episodic_return=-270.71551513671875
# global_step=49344, episodic_return=-126.5162353515625
# global_step=49472, episodic_return=-151.42123413085938
# global_step=49488, episodic_return=-83.09720611572266
# global_step=49600, episodic_return=-230.57760620117188
# global_step=49648, episodic_return=-111.28184509277344
# global_step=49664, episodic_return=-348.7998046875
# global_step=49696, episodic_return=-98.95874786376953
# global_step=49728, episodic_return=-109.27423095703125
# global_step=50144, episodic_return=-99.96736907958984
# global_step=50288, episodic_return=-62.73655319213867
# global_step=50384, episodic_return=-82.46514129638672
# global_step=50480, episodic_return=-139.0931854248047
# global_step=50512, episodic_return=-83.11430358886719
# global_step=50576, episodic_return=-224.080810546875
# global_step=50672, episodic_return=-109.43339538574219
# global_step=50736, episodic_return=-56.717140197753906
# global_step=51008, episodic_return=-127.66329956054688
# global_step=51088, episodic_return=20.44062042236328
# global_step=51152, episodic_return=-95.86444854736328
# global_step=51280, episodic_return=-117.52169799804688
# global_step=51344, episodic_return=-116.0826644897461
# global_step=51472, episodic_return=-342.3839111328125
# global_step=51600, episodic_return=-90.22714233398438
# global_step=51824, episodic_return=-105.12027740478516
# global_step=51856, episodic_return=-108.9175796508789
# global_step=51920, episodic_return=-143.2436981201172
# global_step=51968, episodic_return=-102.8271713256836
# global_step=52016, episodic_return=-250.9869384765625
# global_step=52144, episodic_return=-70.97882080078125
# global_step=52256, episodic_return=-6.521942138671875
# global_step=52352, episodic_return=-99.89262390136719
# global_step=52368, episodic_return=-70.50567626953125
# global_step=52416, episodic_return=-143.8590087890625
# global_step=52656, episodic_return=-232.5151824951172
# global_step=52992, episodic_return=-337.58709716796875
# global_step=53056, episodic_return=-174.80850219726562
# global_step=53232, episodic_return=-74.30274200439453
# global_step=53248, episodic_return=-101.5594711303711
# global_step=53376, episodic_return=-66.66543579101562
# global_step=53440, episodic_return=-155.02316284179688
# global_step=53456, episodic_return=-282.609375
# global_step=53488, episodic_return=-35.488197326660156
# global_step=53616, episodic_return=-117.30068969726562
# global_step=53696, episodic_return=-154.11610412597656
# global_step=53712, episodic_return=-113.5492172241211
# global_step=53824, episodic_return=-77.56695556640625
# global_step=53952, episodic_return=-207.04824829101562
# global_step=54176, episodic_return=-74.07865905761719
# global_step=54192, episodic_return=-100.65154266357422
# global_step=54288, episodic_return=-152.02145385742188
# global_step=54448, episodic_return=-242.4335174560547
# global_step=54624, episodic_return=-88.5570297241211
# global_step=54816, episodic_return=-117.57777404785156
# global_step=54832, episodic_return=-112.68695068359375
# global_step=54944, episodic_return=-204.88681030273438
# global_step=54992, episodic_return=-112.72858428955078
# global_step=55056, episodic_return=-271.8189392089844
# global_step=55168, episodic_return=-207.98553466796875
# global_step=55184, episodic_return=-102.44441986083984
# global_step=55408, episodic_return=-78.41854095458984
# global_step=55504, episodic_return=-122.93108367919922
# global_step=55584, episodic_return=-99.13876342773438
# global_step=55632, episodic_return=-86.81240844726562
# global_step=55744, episodic_return=-117.47314453125
# global_step=55936, episodic_return=-245.0399169921875
# global_step=55984, episodic_return=-71.94902038574219
# global_step=56016, episodic_return=-152.1762237548828
# global_step=56160, episodic_return=-87.03353881835938
# global_step=56192, episodic_return=-196.58578491210938
# global_step=56240, episodic_return=-65.7000732421875
# global_step=56272, episodic_return=-141.0791015625
# global_step=56320, episodic_return=-189.3507080078125
# global_step=56544, episodic_return=-82.89447021484375
# global_step=56688, episodic_return=-64.06578063964844
# global_step=56880, episodic_return=-326.83612060546875
# global_step=57056, episodic_return=-96.32514190673828
# global_step=57120, episodic_return=-119.31863403320312
# global_step=57152, episodic_return=-131.774658203125
# global_step=57264, episodic_return=-94.95919036865234
# global_step=57280, episodic_return=-140.0576629638672
# global_step=57328, episodic_return=-325.1767883300781
# global_step=57360, episodic_return=-320.035400390625
# global_step=57456, episodic_return=-218.38204956054688
# global_step=57680, episodic_return=-143.05120849609375
# global_step=57760, episodic_return=-98.85214233398438
# global_step=57936, episodic_return=-66.45771789550781
# global_step=57968, episodic_return=-148.989013671875
# global_step=58048, episodic_return=-85.2059097290039
# global_step=58288, episodic_return=-70.3458480834961
# global_step=58528, episodic_return=-45.88591766357422
# global_step=58608, episodic_return=-143.68939208984375
# global_step=58624, episodic_return=-56.934478759765625
# global_step=58688, episodic_return=-80.63658905029297
# global_step=58976, episodic_return=-207.59339904785156
# global_step=59056, episodic_return=-142.70623779296875
# global_step=59120, episodic_return=-237.10086059570312
# global_step=59264, episodic_return=-74.09895324707031
# global_step=59296, episodic_return=-125.90239715576172
# global_step=59328, episodic_return=-97.68492126464844
# global_step=59456, episodic_return=-130.02020263671875
# global_step=59536, episodic_return=-211.64065551757812
# global_step=59712, episodic_return=-175.6654815673828
# global_step=59744, episodic_return=-141.00547790527344
# global_step=59856, episodic_return=-104.02322387695312
# global_step=59872, episodic_return=-5.9594879150390625
# global_step=59952, episodic_return=-97.9200439453125
# global_step=60560, episodic_return=-61.67618942260742
# global_step=60768, episodic_return=-100.7261734008789
# global_step=60784, episodic_return=-308.034912109375
# global_step=60800, episodic_return=-307.27728271484375
# global_step=60864, episodic_return=1.7226791381835938
# global_step=60928, episodic_return=-102.09528350830078
# global_step=61008, episodic_return=-166.70169067382812
# global_step=61040, episodic_return=-65.98918151855469
# global_step=61072, episodic_return=-92.10697174072266
# global_step=61104, episodic_return=-152.67776489257812
# global_step=61120, episodic_return=-76.48524475097656
# global_step=61440, episodic_return=-170.491455078125
# global_step=61488, episodic_return=-34.75715637207031
# global_step=61712, episodic_return=-93.24153900146484
# global_step=61776, episodic_return=-310.75140380859375
# global_step=61872, episodic_return=-142.8843994140625
# global_step=62112, episodic_return=-83.4522705078125
# global_step=62320, episodic_return=-113.5059814453125
# global_step=62400, episodic_return=-110.69468688964844
# global_step=62512, episodic_return=-211.28424072265625
# global_step=62640, episodic_return=-8.713180541992188
# global_step=62736, episodic_return=-64.41234588623047
# global_step=62784, episodic_return=-234.3492431640625
# global_step=62864, episodic_return=-94.2060317993164
# global_step=62944, episodic_return=-136.05291748046875
# global_step=63152, episodic_return=-10.774932861328125
# global_step=63248, episodic_return=-176.10794067382812
# global_step=63312, episodic_return=-194.3780517578125
# global_step=63376, episodic_return=-104.44264221191406
# global_step=63408, episodic_return=-79.04547882080078
# global_step=63424, episodic_return=-187.5029296875
# global_step=63616, episodic_return=-92.31033325195312
# global_step=63648, episodic_return=-172.97055053710938
# global_step=63792, episodic_return=-149.32687377929688
# global_step=63904, episodic_return=-92.74349975585938
# global_step=64032, episodic_return=-254.10391235351562
# global_step=64048, episodic_return=-84.98310089111328
# global_step=64272, episodic_return=-105.93533325195312
# global_step=64464, episodic_return=-94.4565200805664
# global_step=64512, episodic_return=-143.5196075439453
# global_step=64528, episodic_return=-325.93878173828125
# global_step=64704, episodic_return=-84.3670425415039
# global_step=64752, episodic_return=-128.48191833496094
# global_step=64976, episodic_return=-143.68214416503906
# global_step=64992, episodic_return=-200.7930908203125
# global_step=65024, episodic_return=-99.92162322998047
# global_step=65184, episodic_return=-113.03910064697266
# global_step=65248, episodic_return=-266.75823974609375
# global_step=65296, episodic_return=-251.53111267089844
# global_step=65408, episodic_return=-175.47332763671875
# SPS: 2826
# global_step=65600, episodic_return=-22.954238891601562
# global_step=65664, episodic_return=-220.79843139648438
# global_step=65808, episodic_return=-94.1808853149414
# global_step=65840, episodic_return=-239.3444366455078
# global_step=66112, episodic_return=-74.93094635009766
# global_step=66192, episodic_return=-98.947998046875
# global_step=66208, episodic_return=-324.7066345214844
# global_step=66272, episodic_return=-68.80465698242188
# global_step=66608, episodic_return=-201.67874145507812
# global_step=66624, episodic_return=-141.86940002441406
# global_step=66720, episodic_return=-96.85597229003906
# global_step=66912, episodic_return=-105.52147674560547
# global_step=66944, episodic_return=-171.18185424804688
# global_step=67184, episodic_return=-404.3729553222656
# global_step=67248, episodic_return=-254.88140869140625
# global_step=67392, episodic_return=-228.14332580566406
# global_step=67536, episodic_return=-121.00098419189453
# global_step=67632, episodic_return=-145.1734161376953
# global_step=67680, episodic_return=-231.04400634765625
# global_step=67888, episodic_return=-283.7073059082031
# global_step=68000, episodic_return=-102.82119750976562
# global_step=68016, episodic_return=-235.0326385498047
# global_step=68128, episodic_return=-37.154144287109375
# global_step=68480, episodic_return=-161.22616577148438
# global_step=68496, episodic_return=-149.48094177246094
# global_step=68640, episodic_return=-107.3225326538086
# global_step=68656, episodic_return=-112.01226043701172
# global_step=68736, episodic_return=-75.17770385742188
# global_step=68768, episodic_return=-97.28721618652344
# global_step=69008, episodic_return=-53.526145935058594
# global_step=69216, episodic_return=-75.25885009765625
# global_step=69232, episodic_return=-42.580238342285156
# global_step=69536, episodic_return=-111.83016967773438
# global_step=69552, episodic_return=-86.3722915649414
# global_step=69616, episodic_return=-137.96173095703125
# global_step=69648, episodic_return=-135.46664428710938
# global_step=69728, episodic_return=-387.4290466308594
# global_step=69936, episodic_return=-68.23933410644531
# global_step=70208, episodic_return=-112.07073211669922
# global_step=70256, episodic_return=-168.85079956054688
# global_step=70336, episodic_return=-133.18392944335938
# global_step=70400, episodic_return=-154.05682373046875
# global_step=70416, episodic_return=-144.06768798828125
# global_step=70432, episodic_return=-229.3061981201172
# global_step=70608, episodic_return=-310.3148193359375
# global_step=70656, episodic_return=-57.76767349243164
# global_step=70688, episodic_return=-120.2017822265625
# global_step=70928, episodic_return=-120.80863952636719
# global_step=71024, episodic_return=-237.5193634033203
# global_step=71200, episodic_return=-109.75472259521484
# global_step=71408, episodic_return=-152.2316131591797
# global_step=71424, episodic_return=-52.482627868652344
# global_step=71584, episodic_return=-115.5394287109375
# global_step=71616, episodic_return=-62.07122802734375
# global_step=71632, episodic_return=-55.561893463134766
# global_step=71856, episodic_return=-233.18113708496094
# global_step=71920, episodic_return=-197.87464904785156
# global_step=71968, episodic_return=-198.92247009277344
# global_step=72032, episodic_return=-134.36146545410156
# global_step=72096, episodic_return=-129.18417358398438
# global_step=72224, episodic_return=-155.34849548339844
# global_step=72320, episodic_return=-223.00674438476562
# global_step=72464, episodic_return=-163.6349639892578
# global_step=72672, episodic_return=-171.39794921875
# global_step=72768, episodic_return=-319.11236572265625
# global_step=72784, episodic_return=-95.5520248413086
# global_step=72944, episodic_return=-81.08465576171875
# global_step=73008, episodic_return=-169.63241577148438
# global_step=73136, episodic_return=-143.3330078125
# global_step=73360, episodic_return=-62.954017639160156
# global_step=73392, episodic_return=-24.601181030273438
# global_step=73664, episodic_return=-73.616455078125
# global_step=73696, episodic_return=-88.30056762695312
# global_step=73792, episodic_return=-154.74586486816406
# global_step=73920, episodic_return=-196.53598022460938
# global_step=73936, episodic_return=-131.4642333984375
# global_step=74032, episodic_return=-207.27798461914062
# global_step=74080, episodic_return=-219.09469604492188
# global_step=74336, episodic_return=-103.52305603027344
# global_step=74384, episodic_return=-147.5009002685547
# global_step=74544, episodic_return=-138.1074981689453
# global_step=74560, episodic_return=-103.99015045166016
# global_step=74896, episodic_return=-98.01013946533203
# global_step=74912, episodic_return=-109.42998504638672
# global_step=75056, episodic_return=-21.96484375
# global_step=75088, episodic_return=-157.46725463867188
# global_step=75136, episodic_return=-103.89115905761719
# global_step=75152, episodic_return=-97.24024200439453
# global_step=75168, episodic_return=-105.08775329589844
# global_step=75184, episodic_return=-106.95185089111328
# global_step=75200, episodic_return=-218.76071166992188
# global_step=75248, episodic_return=-111.91506958007812
# global_step=75472, episodic_return=-122.97203063964844
# global_step=76000, episodic_return=-59.0975227355957
# global_step=76160, episodic_return=-122.27115631103516
# global_step=76224, episodic_return=-104.04107666015625
# global_step=76240, episodic_return=-230.9318389892578
# global_step=76256, episodic_return=-151.504150390625
# global_step=76448, episodic_return=-48.211151123046875
# global_step=76528, episodic_return=-90.54131317138672
# global_step=76544, episodic_return=-63.9196662902832
# global_step=76688, episodic_return=-84.64415740966797
# global_step=76864, episodic_return=-104.94972229003906
# global_step=76896, episodic_return=-195.4523468017578
# global_step=77024, episodic_return=-134.15321350097656
# global_step=77216, episodic_return=-78.96430206298828
# global_step=77248, episodic_return=-90.66879272460938
# global_step=77280, episodic_return=-59.579559326171875
# global_step=77296, episodic_return=-88.10983276367188
# global_step=77376, episodic_return=-375.2876892089844
# global_step=77584, episodic_return=-137.8285675048828
# global_step=77792, episodic_return=-105.77369689941406
# global_step=77824, episodic_return=-97.12955474853516
# global_step=77936, episodic_return=-122.8808364868164
# global_step=78048, episodic_return=-122.92817687988281
# global_step=78240, episodic_return=-96.29995727539062
# global_step=78272, episodic_return=-108.60157012939453
# global_step=78336, episodic_return=-57.377445220947266
# global_step=78592, episodic_return=-112.36517333984375
# global_step=78608, episodic_return=-100.92816925048828
# global_step=78656, episodic_return=-70.07294464111328
# global_step=78816, episodic_return=-197.54855346679688
# global_step=78880, episodic_return=-343.553955078125
# global_step=78976, episodic_return=-353.37744140625
# global_step=79216, episodic_return=-122.76023864746094
# global_step=79280, episodic_return=-170.0066375732422
# global_step=79472, episodic_return=-104.57974243164062
# global_step=79600, episodic_return=-87.42044830322266
# global_step=79728, episodic_return=-83.19597625732422
# global_step=79760, episodic_return=-156.32249450683594
# global_step=79824, episodic_return=-116.1086196899414
# global_step=79856, episodic_return=-106.35367584228516
# global_step=79968, episodic_return=-258.84326171875
# global_step=80048, episodic_return=-84.0728759765625
# global_step=80096, episodic_return=-62.53388977050781
# global_step=80336, episodic_return=-77.67195129394531
# global_step=80384, episodic_return=7.836112976074219
# global_step=80464, episodic_return=-83.375244140625
# global_step=80704, episodic_return=-100.74506378173828
# global_step=80768, episodic_return=-61.44087219238281
# global_step=80896, episodic_return=-180.05361938476562
# global_step=81008, episodic_return=-88.4519271850586
# global_step=81136, episodic_return=-53.490814208984375
# global_step=81456, episodic_return=-101.56339263916016
# global_step=81536, episodic_return=-109.02567291259766
# global_step=81664, episodic_return=-139.4998016357422
# global_step=81696, episodic_return=-140.5294189453125
# global_step=81920, episodic_return=-168.12286376953125
# SPS: 2880
# global_step=81984, episodic_return=-85.45320129394531
# global_step=82032, episodic_return=-111.41307067871094
# global_step=82064, episodic_return=-110.10511016845703
# global_step=82208, episodic_return=-109.97032928466797
# global_step=82224, episodic_return=-68.79186248779297
# global_step=82304, episodic_return=-177.341064453125
# global_step=82336, episodic_return=-123.24679565429688
# global_step=82368, episodic_return=-168.54299926757812
# global_step=82544, episodic_return=-35.79716491699219
# global_step=82704, episodic_return=-108.43279266357422
# global_step=82960, episodic_return=-100.82140350341797
# global_step=83088, episodic_return=-89.51968383789062
# global_step=83168, episodic_return=-75.65757751464844
# global_step=83200, episodic_return=-66.4730224609375
# global_step=83472, episodic_return=-192.85696411132812
# global_step=83584, episodic_return=-119.11050415039062
# global_step=83680, episodic_return=-120.63390350341797
# global_step=83712, episodic_return=-55.16646957397461
# global_step=83728, episodic_return=-243.08432006835938
# global_step=83984, episodic_return=-124.12834167480469
# global_step=84192, episodic_return=-108.01121520996094
# global_step=84368, episodic_return=-143.00282287597656
# global_step=84464, episodic_return=-107.15081787109375
# global_step=84480, episodic_return=-177.8677520751953
# global_step=84672, episodic_return=-55.29595947265625
# global_step=84768, episodic_return=-118.98878479003906
# global_step=84784, episodic_return=-189.81182861328125
# global_step=84832, episodic_return=-132.5496826171875
# global_step=84880, episodic_return=-273.74273681640625
# global_step=85008, episodic_return=-63.47406005859375
# global_step=85024, episodic_return=-36.41820526123047
# global_step=85072, episodic_return=-115.52816772460938
# global_step=85472, episodic_return=-111.86075592041016
# global_step=85744, episodic_return=-271.2944030761719
# global_step=85760, episodic_return=-193.84420776367188
# global_step=85776, episodic_return=-250.93148803710938
# global_step=85840, episodic_return=40.76582336425781
# global_step=86064, episodic_return=-165.50604248046875
# global_step=86192, episodic_return=-107.80650329589844
# global_step=86288, episodic_return=-115.61007690429688
# global_step=86496, episodic_return=-167.55157470703125
# global_step=86512, episodic_return=-203.90240478515625
# global_step=86592, episodic_return=-91.11048889160156
# global_step=86704, episodic_return=-157.6017303466797
# global_step=86784, episodic_return=-128.12918090820312
# global_step=86896, episodic_return=-95.4459457397461
# global_step=86944, episodic_return=-59.40263366699219
# global_step=87008, episodic_return=-114.0623550415039
# global_step=87136, episodic_return=-169.730712890625
# global_step=87488, episodic_return=-96.73057556152344
# global_step=87712, episodic_return=-132.60630798339844
# global_step=87760, episodic_return=-165.5306396484375
# global_step=87792, episodic_return=-102.29271697998047
# global_step=87824, episodic_return=-140.13677978515625
# global_step=87856, episodic_return=-227.34507751464844
# global_step=87888, episodic_return=-69.69456481933594
# global_step=88000, episodic_return=-89.95869445800781
# global_step=88336, episodic_return=-123.65023803710938
# global_step=88368, episodic_return=-121.42498779296875
# global_step=88464, episodic_return=-292.4151916503906
# global_step=88480, episodic_return=-35.1337890625
# global_step=88640, episodic_return=-220.68890380859375
# global_step=88784, episodic_return=-72.73631286621094
# global_step=88864, episodic_return=-75.67749786376953
# global_step=88896, episodic_return=-106.621337890625
# global_step=88912, episodic_return=-97.13285827636719
# global_step=89088, episodic_return=-213.74441528320312
# global_step=89200, episodic_return=-95.16632080078125
# global_step=89248, episodic_return=-122.6640625
# global_step=89328, episodic_return=-91.72344970703125
# global_step=89696, episodic_return=-129.63204956054688
# global_step=89824, episodic_return=-138.82296752929688
# global_step=90096, episodic_return=-132.09251403808594
# global_step=90128, episodic_return=-99.02976989746094
# global_step=90304, episodic_return=-153.4839324951172
# global_step=90368, episodic_return=-45.910221099853516
# ...
# global_step=745856, episodic_return=-37.09314727783203
# global_step=747808, episodic_return=13.804429054260254
# global_step=749936, episodic_return=-56.09326934814453
# global_step=750400, episodic_return=-8.85500717163086
# global_step=751920, episodic_return=-19.801498413085938
# global_step=752064, episodic_return=-57.90840530395508
# global_step=752672, episodic_return=-73.62544250488281
# SPS: 1007
# global_step=755440, episodic_return=7.802353382110596
# global_step=755728, episodic_return=8.104094505310059
# global_step=756560, episodic_return=-9.986712455749512
# global_step=759584, episodic_return=78.63367462158203
# global_step=759632, episodic_return=12.357104301452637
# global_step=759712, episodic_return=-35.58080291748047
# global_step=760560, episodic_return=-49.039306640625
# global_step=761840, episodic_return=-24.757190704345703
# global_step=761856, episodic_return=-32.98968505859375
# global_step=763808, episodic_return=-21.11659049987793
# global_step=765936, episodic_return=-11.775323867797852
# global_step=766400, episodic_return=-11.32288932800293
# global_step=767920, episodic_return=-75.23767852783203
# global_step=768064, episodic_return=-20.024398803710938
# global_step=768672, episodic_return=-98.88506317138672
# SPS: 989
# global_step=771440, episodic_return=-41.17448043823242
# global_step=771728, episodic_return=-50.60972213745117
# global_step=772560, episodic_return=40.5203857421875
# global_step=775584, episodic_return=-62.86912155151367
# global_step=775632, episodic_return=-49.38764190673828
# global_step=775712, episodic_return=-21.214242935180664
# global_step=776560, episodic_return=16.50482749938965
# global_step=777840, episodic_return=-98.54612731933594
# global_step=777856, episodic_return=-52.08161926269531
# global_step=779808, episodic_return=-75.10488891601562
# global_step=781936, episodic_return=-58.588932037353516
# global_step=782400, episodic_return=-110.59845733642578
# global_step=783920, episodic_return=-40.78063201904297
# global_step=784064, episodic_return=-28.22757911682129
# global_step=784672, episodic_return=-69.604248046875
# SPS: 977
# global_step=787440, episodic_return=-96.86910247802734
# global_step=787728, episodic_return=2.5718963146209717
# global_step=788560, episodic_return=-61.45207977294922
# global_step=791584, episodic_return=-61.151268005371094
# global_step=791632, episodic_return=-22.362979888916016
# global_step=791712, episodic_return=-82.28134155273438
# global_step=792560, episodic_return=-38.77355194091797
# global_step=793840, episodic_return=-35.359458923339844
# global_step=793856, episodic_return=-66.70519256591797
# global_step=795808, episodic_return=-60.31380081176758
# global_step=797936, episodic_return=5.316726207733154
# global_step=798400, episodic_return=2.508979082107544
# global_step=799920, episodic_return=-8.28132152557373
# global_step=800064, episodic_return=-66.26689910888672
# global_step=800672, episodic_return=-20.614904403686523
# SPS: 967
# global_step=803440, episodic_return=-42.76753234863281
# global_step=803728, episodic_return=-26.630361557006836
# global_step=804560, episodic_return=-46.11769485473633
# global_step=807584, episodic_return=-36.04255294799805
# global_step=807632, episodic_return=-43.19883346557617
# global_step=807712, episodic_return=-91.7063217163086
# global_step=808560, episodic_return=-57.35855484008789
# global_step=809840, episodic_return=-64.5593490600586
# global_step=809856, episodic_return=-36.86104202270508
# global_step=811808, episodic_return=-61.8238410949707
# global_step=813936, episodic_return=-61.415679931640625
# global_step=814400, episodic_return=-41.391700744628906
# global_step=815920, episodic_return=-19.387279510498047
# global_step=816064, episodic_return=-23.038755416870117
# global_step=816672, episodic_return=-52.23060989379883
# SPS: 955
# global_step=819440, episodic_return=-15.935518264770508
# global_step=819728, episodic_return=-40.31439971923828
# global_step=820560, episodic_return=-46.31856918334961
# global_step=823584, episodic_return=-50.915771484375
# global_step=823632, episodic_return=-57.10965347290039
# global_step=823712, episodic_return=-24.058809280395508
# global_step=824560, episodic_return=-52.09393310546875
# global_step=825840, episodic_return=-27.919235229492188
# global_step=825856, episodic_return=-22.3601131439209
# global_step=827808, episodic_return=-18.630266189575195
# global_step=829936, episodic_return=-47.20053482055664
# global_step=830400, episodic_return=-40.91317367553711
# global_step=831920, episodic_return=-39.32439041137695
# global_step=832064, episodic_return=-53.18571853637695
# global_step=832672, episodic_return=31.69143295288086
# global_step=835440, episodic_return=-2.6084606647491455
# SPS: 943
# global_step=835728, episodic_return=1.078978419303894
# global_step=836560, episodic_return=5.400619029998779
# global_step=839584, episodic_return=-19.932966232299805
# global_step=839632, episodic_return=-52.55421447753906
# global_step=839712, episodic_return=-63.91484832763672
# global_step=840560, episodic_return=-40.138221740722656
# global_step=841840, episodic_return=-71.30529022216797
# global_step=841856, episodic_return=-36.840763092041016
# global_step=843808, episodic_return=-3.5477960109710693
# global_step=845936, episodic_return=-42.488609313964844
# global_step=846400, episodic_return=-18.8413143157959
# global_step=847920, episodic_return=12.441234588623047
# global_step=848064, episodic_return=-2.3760547637939453
# global_step=848672, episodic_return=-13.792573928833008
# global_step=851168, episodic_return=-93.29425811767578
# global_step=851440, episodic_return=0.5439380407333374
# SPS: 935
# global_step=852560, episodic_return=-20.442590713500977
# global_step=855584, episodic_return=5.617112636566162
# global_step=855632, episodic_return=-46.53750228881836
# global_step=855712, episodic_return=-50.42402648925781
# global_step=856560, episodic_return=-4.25016975402832
# global_step=857840, episodic_return=-10.645037651062012
# global_step=857856, episodic_return=-10.009429931640625
# global_step=859808, episodic_return=-24.61307144165039
# global_step=861936, episodic_return=-71.70923614501953
# global_step=862160, episodic_return=-132.1636962890625
# global_step=863920, episodic_return=7.069490432739258
# global_step=864064, episodic_return=-58.91592025756836
# global_step=864672, episodic_return=-14.068313598632812
# global_step=867168, episodic_return=-53.08543014526367
# global_step=867440, episodic_return=4.81681489944458
# SPS: 927
# global_step=868560, episodic_return=-59.01811218261719
# global_step=871584, episodic_return=-35.73882293701172
# global_step=871632, episodic_return=-32.76932144165039
# global_step=871712, episodic_return=-41.79187774658203
# global_step=872560, episodic_return=-38.03692626953125
# global_step=873840, episodic_return=-84.46305084228516
# global_step=873856, episodic_return=-54.35830307006836
# global_step=875808, episodic_return=-45.28117752075195
# global_step=877936, episodic_return=-97.43524169921875
# global_step=878160, episodic_return=-69.26810455322266
# global_step=879920, episodic_return=-15.488874435424805
# global_step=880064, episodic_return=-9.010194778442383
# global_step=880672, episodic_return=-16.46945571899414
# global_step=882976, episodic_return=-93.846923828125
# global_step=883168, episodic_return=-34.78554153442383
# global_step=883440, episodic_return=-62.22875213623047
# global_step=884560, episodic_return=-46.463809967041016
# SPS: 920
# global_step=887632, episodic_return=-28.569561004638672
# global_step=887712, episodic_return=-24.224998474121094
# global_step=888560, episodic_return=-64.75236511230469
# global_step=889840, episodic_return=-47.53144836425781
# global_step=889856, episodic_return=-76.2373275756836
# global_step=891808, episodic_return=-63.09095001220703
# global_step=893936, episodic_return=-64.3909912109375
# global_step=894160, episodic_return=-69.13726806640625
# global_step=895920, episodic_return=-47.732688903808594
# global_step=896064, episodic_return=-79.99195098876953
# global_step=896672, episodic_return=-17.49022102355957
# global_step=898976, episodic_return=-25.026212692260742
# global_step=899168, episodic_return=-44.224693298339844
# global_step=899440, episodic_return=-57.305702209472656
# global_step=900560, episodic_return=-60.117549896240234
# SPS: 912
# global_step=903632, episodic_return=-30.529293060302734
# global_step=903712, episodic_return=-50.61562728881836
# global_step=904384, episodic_return=-125.05267333984375
# global_step=904560, episodic_return=-75.34943389892578
# global_step=905840, episodic_return=-11.066044807434082
# global_step=907808, episodic_return=-57.960880279541016
# global_step=909936, episodic_return=-88.09038543701172
# global_step=910160, episodic_return=-79.35802459716797
# global_step=911920, episodic_return=-71.99474334716797
# global_step=912064, episodic_return=-40.559574127197266
# global_step=912672, episodic_return=-20.729951858520508
# global_step=914976, episodic_return=-34.89371871948242
# global_step=915168, episodic_return=-60.83966827392578
# global_step=915440, episodic_return=-32.922119140625
# global_step=916560, episodic_return=-62.04962921142578
# SPS: 903
# global_step=919632, episodic_return=-16.705747604370117
# global_step=919712, episodic_return=-83.00220489501953
# global_step=920384, episodic_return=-63.214237213134766
# global_step=920560, episodic_return=-13.603204727172852
# global_step=921840, episodic_return=-19.764667510986328
# global_step=923808, episodic_return=-49.1024055480957
# global_step=925936, episodic_return=-40.36162567138672
# global_step=926160, episodic_return=-26.26399803161621
# global_step=927920, episodic_return=-32.27657699584961
# global_step=928064, episodic_return=-30.54542350769043
# global_step=928672, episodic_return=-43.302371978759766
# global_step=930976, episodic_return=-55.2562370300293
# global_step=931168, episodic_return=-60.46529006958008
# global_step=931440, episodic_return=-21.014284133911133
# global_step=932560, episodic_return=-2.3327078819274902
# SPS: 893
# global_step=935632, episodic_return=-46.777889251708984
# global_step=935712, episodic_return=-55.85356903076172
# global_step=936384, episodic_return=-39.14579772949219
# global_step=936560, episodic_return=-48.86825180053711
# global_step=937840, episodic_return=-25.972436904907227
# global_step=939808, episodic_return=-18.061309814453125
# global_step=941936, episodic_return=-28.50227928161621
# global_step=942160, episodic_return=-16.178272247314453
# global_step=943920, episodic_return=-31.16666030883789
# global_step=944064, episodic_return=-10.303422927856445
# global_step=944672, episodic_return=-54.4242057800293
# global_step=946976, episodic_return=15.426554679870605
# global_step=947168, episodic_return=-72.47555541992188
# global_step=947440, episodic_return=-76.3385009765625
# global_step=948560, episodic_return=-32.69784927368164
# global_step=948736, episodic_return=-128.80209350585938
# SPS: 887
# global_step=951632, episodic_return=-93.77393341064453
# global_step=952384, episodic_return=-5.584721088409424
# global_step=952560, episodic_return=-19.87587547302246
# global_step=953840, episodic_return=18.99138832092285
# global_step=955808, episodic_return=-69.81041717529297
# global_step=957936, episodic_return=-90.87081909179688
# global_step=958160, episodic_return=-24.207441329956055
# global_step=959920, episodic_return=-57.140445709228516
# global_step=960064, episodic_return=-47.874183654785156
# global_step=960672, episodic_return=-59.70409393310547
# global_step=962976, episodic_return=-58.57317352294922
# global_step=963168, episodic_return=-50.90121078491211
# global_step=963440, episodic_return=-3.069378137588501
# global_step=964560, episodic_return=-34.881465911865234
# global_step=964736, episodic_return=-16.174095153808594
# SPS: 879
# global_step=967632, episodic_return=-28.36850357055664
# global_step=968384, episodic_return=-38.97354507446289
# global_step=968560, episodic_return=-35.393028259277344
# global_step=969840, episodic_return=-46.70807647705078
# global_step=971808, episodic_return=-72.43460083007812
# global_step=973936, episodic_return=-26.66244888305664
# global_step=974160, episodic_return=-80.98158264160156
# global_step=975920, episodic_return=-70.65483093261719
# global_step=976064, episodic_return=-20.82755470275879
# global_step=976672, episodic_return=-17.952926635742188
# global_step=978976, episodic_return=-24.404525756835938
# global_step=979168, episodic_return=-15.646651268005371
# global_step=979440, episodic_return=-22.7937068939209
# global_step=980560, episodic_return=-41.503318786621094
# global_step=980736, episodic_return=-18.533647537231445
# SPS: 872
# global_step=983632, episodic_return=-20.04002571105957
# global_step=984384, episodic_return=-43.048404693603516
# global_step=984560, episodic_return=-83.1815414428711
# global_step=985840, episodic_return=-7.428437232971191
# global_step=987808, episodic_return=-53.45641326904297
# global_step=989936, episodic_return=-64.7074966430664
# global_step=990160, episodic_return=-17.598058700561523
# global_step=991920, episodic_return=-17.41278076171875
# global_step=992064, episodic_return=-23.447025299072266
# global_step=992672, episodic_return=-34.65542984008789
# global_step=994976, episodic_return=-25.816532135009766
# global_step=995168, episodic_return=-7.749979019165039
# global_step=995440, episodic_return=-34.42374038696289
# global_step=996560, episodic_return=39.04469680786133
# global_step=996736, episodic_return=-63.803680419921875
# SPS: 867
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ℹ Pushing repo Chiz/ppo-LunarLander-v2 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...7928.86cf83882442.13633.0: 100% 397k/397k [00:00<?, ?B/s]
#
#
#   /tmp/tmpc0m_uo87/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
#   /tmp/tmpc0m_uo87/replay.mp4 : 100% 237k/237k [00:00<?, ?B/s]
#
#   ...7928.86cf83882442.13633.0: 100% 397k/397k [00:00<?, ?B/s]
#
#
#   /tmp/tmpc0m_uo87/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 678k/678k [00:00<00:00, 838kB/s, 1.13MB/s  ]
# New Data Upload               : 100% 678k/678k [00:00<00:00, 838kB/s, 1.13MB/s  ]
#
#   ...7928.86cf83882442.13633.0: 100% 397k/397k [00:00<?, ?B/s]
#
#
#   /tmp/tmpc0m_uo87/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
#   /tmp/tmpc0m_uo87/replay.mp4 : 100% 237k/237k [00:00<?, ?B/s]
#
#   ...7928.86cf83882442.13633.0: 100% 397k/397k [00:00<?, ?B/s]
#
#
#   /tmp/tmpc0m_uo87/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 678k/678k [00:01<00:00, 671kB/s,  847kB/s  ]
# New Data Upload               : 100% 678k/678k [00:01<00:00, 672kB/s,  847kB/s  ]
#   ...7928.86cf83882442.13633.0: 100% 397k/397k [00:00<?, ?B/s]
#   /tmp/tmpc0m_uo87/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#   /tmp/tmpc0m_uo87/replay.mp4 : 100% 237k/237k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Chiz/ppo-LunarLander-v2/commit/6d5bf9f4b3157358049032b0199659980db45a2d

# %%
# !python ppo.py \
  --env-id="LunarLander-v3" \
  --repo-id="Chiz/ppo-LunarLander-v3-02" \
  --total-timesteps=5000000 \
  --learning-rate=2e-4 \
  --num-envs=16 \
  --num-steps=2048 \
  --gamma=0.999 \
  --gae-lambda=0.95 \
  --num-minibatches=32 \
  --update-epochs=10 \
  --ent-coef=0.01 \
  --anneal-lr=True
# Out:
# 2026-02-18 15:53:23.695390: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771430003.716647    9148 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771430003.723806    9148 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771430003.742137    9148 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771430003.742159    9148 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771430003.742163    9148 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771430003.742168    9148 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-18 15:53:23.747178: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# SPS: 3357
# SPS: 3494
# SPS: 3588
# SPS: 3588
# SPS: 3517
# SPS: 3503
# SPS: 3546
# SPS: 3554
# SPS: 3551
# SPS: 3540
# SPS: 3558
# SPS: 3549
# SPS: 3541
# SPS: 3528
# SPS: 3541
# SPS: 3538
# SPS: 3535
# SPS: 3528
# SPS: 3533
# SPS: 3537
# SPS: 3539
# SPS: 3538
# SPS: 3549
# SPS: 3553
# SPS: 3556
# SPS: 3555
# SPS: 3565
# SPS: 3566
# SPS: 3566
# SPS: 3563
# SPS: 3570
# SPS: 3568
# SPS: 3567
# SPS: 3564
# SPS: 3570
# SPS: 3569
# SPS: 3568
# SPS: 3563
# SPS: 3564
# SPS: 3566
# SPS: 3566
# SPS: 3564
# SPS: 3566
# SPS: 3568
# SPS: 3568
# SPS: 3566
# SPS: 3565
# SPS: 3568
# SPS: 3567
# SPS: 3567
# SPS: 3564
# SPS: 3568
# SPS: 3568
# SPS: 3566
# SPS: 3563
# SPS: 3567
# SPS: 3566
# SPS: 3566
# SPS: 3563
# SPS: 3566
# SPS: 3565
# SPS: 3565
# SPS: 3562
# SPS: 3563
# SPS: 3563
# SPS: 3560
# SPS: 3556
# SPS: 3553
# SPS: 3555
# SPS: 3553
# SPS: 3552
# SPS: 3548
# SPS: 3545
# SPS: 3546
# SPS: 3544
# SPS: 3542
# SPS: 3539
# SPS: 3540
# SPS: 3538
# SPS: 3536
# SPS: 3534
# SPS: 3532
# SPS: 3533
# SPS: 3532
# SPS: 3530
# SPS: 3528
# SPS: 3529
# SPS: 3529
# SPS: 3528
# SPS: 3526
# SPS: 3524
# SPS: 3526
# SPS: 3525
# SPS: 3524
# SPS: 3521
# SPS: 3521
# SPS: 3521
# SPS: 3521
# SPS: 3520
# SPS: 3519
# SPS: 3521
# SPS: 3520
# SPS: 3520
# SPS: 3518
# SPS: 3517
# SPS: 3517
# SPS: 3517
# SPS: 3516
# SPS: 3515
# SPS: 3517
# SPS: 3516
# SPS: 3516
# SPS: 3515
# SPS: 3517
# SPS: 3517
# SPS: 3517
# SPS: 3516
# SPS: 3516
# SPS: 3516
# SPS: 3515
# SPS: 3514
# SPS: 3513
# SPS: 3515
# SPS: 3514
# SPS: 3513
# SPS: 3512
# SPS: 3512
# SPS: 3513
# SPS: 3513
# SPS: 3512
# SPS: 3510
# SPS: 3511
# SPS: 3511
# SPS: 3510
# SPS: 3510
# SPS: 3510
# SPS: 3510
# SPS: 3510
# SPS: 3509
# SPS: 3508
# SPS: 3510
# SPS: 3510
# SPS: 3510
# SPS: 3509
# SPS: 3511
# SPS: 3511
# SPS: 3511
# SPS: 3510
# SPS: 3511
# SPS: 3511
# SPS: 3511
# SPS: 3510
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ℹ Pushing repo Chiz/ppo-LunarLander-v3-02 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...30010.791a818e4bed.9148.0: 100% 79.8k/79.8k [00:00<?, ?B/s]
#
#
#   /tmp/tmp9owgl7t7/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
#   /tmp/tmp9owgl7t7/replay.mp4 : 100% 155k/155k [00:00<?, ?B/s]
#
#   ...30010.791a818e4bed.9148.0: 100% 79.8k/79.8k [00:00<?, ?B/s]
#
#
#   /tmp/tmp9owgl7t7/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 278k/278k [00:00<00:00, 342kB/s,  463kB/s  ]
# New Data Upload               : 100% 278k/278k [00:00<00:00, 343kB/s,  463kB/s  ]
#
#   ...30010.791a818e4bed.9148.0: 100% 79.8k/79.8k [00:00<?, ?B/s]
#
#
#   /tmp/tmp9owgl7t7/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
#   /tmp/tmp9owgl7t7/replay.mp4 : 100% 155k/155k [00:00<?, ?B/s]
#
#   ...30010.791a818e4bed.9148.0: 100% 79.8k/79.8k [00:00<?, ?B/s]
#
#
#   /tmp/tmp9owgl7t7/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 278k/278k [00:01<00:00, 275kB/s,  347kB/s  ]
# New Data Upload               : 100% 278k/278k [00:01<00:00, 275kB/s,  347kB/s  ]
#   ...30010.791a818e4bed.9148.0: 100% 79.8k/79.8k [00:00<?, ?B/s]
#   /tmp/tmp9owgl7t7/model.pt   : 100% 43.4k/43.4k [00:00<?, ?B/s]
#   /tmp/tmp9owgl7t7/replay.mp4 : 100% 155k/155k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Chiz/ppo-LunarLander-v3-02/commit/1341da3d2e9e69a307bc5140f6257ea81aa85c31

# %% [markdown]
# ### **Huggingface mean_reward on LunarLander-v2 self-reported: 137.76 +/- 84.47**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  another environment?

# %% [markdown]
# See you on Unit 8, part 2 where we going to train agents to play Doom 🔥
# ## Keep learning, stay awesome 🤗
